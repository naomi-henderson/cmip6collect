# %% [markdown]
# # To Handle New Data Requests Automatically
# - beginning of notebook is assumed to be interactive until the requests have been checked
# - all progress and exception logging is done only for main loop
# - copy and paste the e-mail response and send from gcs.cmip6.ldeo@gmail.com account

# %%
import numpy as np
import pandas as pd
import os
import gcsfs
import xarray as xr

# %% [markdown]
# ### Local modules

# %%
from request import requests, set_request_id
from search import search, esgf_search_sites
from netcdf import get_ncfiles, concatenate
from identify import needed
from response import response, dict_to_dfcat, get_details

# %% [markdown]
# ### Initialization

# %%
fs = gcsfs.GCSFileSystem(token='anon', access='read_only')

# Where to write NEW zarr stores:
zarr_local = '/h62/naomi/zarr-minimal'

# %% [markdown]
# ### Choose basic configuration parameters

# %%
dtype = esgf_search_sites()
print('possible ESGF API search nodes: ',list(dtype.keys()))
ESGF_site = dtype['llnl']
#ESGF_site = dtype['gfdl']
#ESGF_site = dtype['ipsl']

# List sites to skip for aquiring new netcdf files: broken or slow sites
skip_sites = ['esg.lasg.ac.cn'] #,'esgf-data1.llnl.gov'] #['dist.nmlab.snu.ac.kr','esg.lasg.ac.cn'] #,'aims3.llnl.gov'] #,'esgf-data2.diasjp.net']
# Out:
# possible ESGF API search nodes:  ['llnl', 'ipsl', 'nci', 'ceda', 'jpl', 'gfdl', 'dkrz']

# %% [markdown]
# ### Get prior Google Sheet requests

# %%
df_prior = pd.read_csv('csv/requests.csv')
#df_prior

# %% [markdown]
# ### Get new Google Sheet requests
# - by default, only the new rows from the sheet are considered
# - specifying a list of rows or emails will add older entries

# %%
rows = []   
emails = []

# modify here:
rows = [104]
#emails = ['orianac@uw.edu']

df_request_new, dtrouble = requests(df_prior,rows=rows,emails=emails)

request_id = set_request_id()

# Check for mal-formed requests (non-existent variables, etc)
if len(dtrouble)>=1:
    print(dtrouble)

df_request_new
# Out:
#               Timestamp                      E-mail                        response status members                                        experiments     models                                          variables table       requester                                            science                                           comments
# 104    2/7/2020 6:05:06      mpb20@st-andrews.ac.uk                                    NaN   [One]       [historical, ssp126, ssp245, ssp370, ssp585]      [All]                                        [tas, huss]   day   Michael Byrne  Hi there,\n\nI'm working on a new paper lookin...  That's it, thanks a lot for setting up this aw...
# 14   9/17/2019 15:17:17    riley.brady@colorado.edu                                   once      []                      [dcppA-hindcast, dcppA-assim]   [MIROC6]                                              [tos]  Omon     Riley Brady  Providing analysis support for initialized dec...  It would be good to also get the available dcp...
# 15   9/17/2019 19:10:50    riley.brady@colorado.edu                                   once      []  [dcppA-assim, dcppA-hindcast, dcppC-hindcast-n...  [CanESM5]                                              [tas]  Amon     Riley Brady  Providing analysis support for initialized dec...                                                NaN
# 16   9/17/2019 19:16:38    riley.brady@colorado.edu                                   once      []                      [dcppA-assim, dcppA-hindcast]  [CanESM5]                                              [tas]   day     Riley Brady  Providing analysis support for initialized dec...  only for a few initialization years (check mem...
# 46    10/4/2019 0:40:58           stephens@ucar.edu  added hist-bgc to list of experiments      []                             [historical, hist-bgc]      [All]  [fgo2, fgco2, fgco2abio, fgco2nat, tos, sos, h...  Omon  Britt Stephens  Testing model representation of seasonal air-s...  These should all be 2d monthly fields, so hope...
# 90     1/8/2020 4:07:13  aaron.spring@mpimet.mpg.de                                   once   [All]  [dcppA-hindcast, dcppB-forecast, esm-piControl...      [All]                           [fgco2, intpp, tos, sos]  Omon    Aaron Spring                    PhD carbon cycle predictability                                                NaN
# 104    2/7/2020 6:05:06      mpb20@st-andrews.ac.uk                                    NaN   [One]       [historical, ssp126, ssp245, ssp370, ssp585]      [All]                                        [tas, huss]   day   Michael Byrne  Hi there,I'm working on a new paper looking at...  That's it, thanks a lot for setting up this aw...
# 106    2/8/2020 0:11:43           nhn2@columbia.edu                                    NaN   [All]                                   [dcppA-hindcast]      [All]                                              [tas]  Amon           Naomi                                                NaN                                                NaN

# %%
# choose a new request to process:
timestamps = df_request_new.Timestamp.unique()
print(timestamps)
df_request_new = df_request_new[df_request_new.Timestamp == timestamps[-1]]
df_request_new
# Out:
# ['2/8/2020 0:11:43']
#             Timestamp             E-mail response status members       experiments models variables table requester science comments
# 106  2/8/2020 0:11:43  nhn2@columbia.edu             NaN   [All]  [dcppA-hindcast]  [All]     [tas]  Amon     Naomi     NaN      NaN

# %% [markdown]
# ### Search ESGF for the availability of requested data

# %%
print(ESGF_site)
df_ESGF = search(ESGF_site,df_request_new)
# Out:
# https://esgf-node.llnl.gov/esg-search/search
#
# nhn2@columbia.edu
# Amon tas ['All'] dcppA-hindcast

# %%
#import qgrid
#qgrid.show_grid(df_ESGF)

# %% [markdown]
# ### Get the master list of existing zarr stores
# - df_master includes all curated stores
# - df_avail includes all stores, even those with known ES-DOC issues

# %%
df_master = pd.read_csv('https://cmip6.storage.googleapis.com/cmip6-zarr-consolidated-stores.csv')
df_avail = pd.read_csv('https://cmip6.storage.googleapis.com/cmip6-zarr-consolidated-stores-noQC.csv')
len(df_master),len(df_avail),len(df_ESGF)
# Out:
# (224788, 225537, 5118)

# %% [markdown]
# ### Check the new requests:
# - already exists in df_master (what we have) - not needed
# - exists in df_ESGF (what is available) - if not available, then not needed

# %%
df_needed = needed(df_avail, df_request_new, df_ESGF)

if len(df_needed) > 0:
    num_stores = df_needed.zstore.nunique() 
    print(f'needed: nfiles={len(df_needed)}, nstores={num_stores}')
    #print(df_needed.zstore.unique())
else:
    print('no new data available')
    exit
# Out:
# needed: nfiles=777, nstores=777

# %%
import qgrid
qgrid.show_grid(df_needed)
#/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1961-r1i1p1f1/Amon/tas/gn/
# Out:
# QgridWidget(grid_options={'fullWidthRows': True, 'syncColumnCellResize': True, 'forceFitColumns': True, 'defau…

# %% [markdown]
# ### Start logging the progress and exceptions

# %%
cat_file = 'csv/cmip6_'+request_id+'.csv'
log_file = 'txt/request_'+request_id+'.log'

# %%
# open and close for each write in case of kernel interrupt
def write_log(file,str,verbose=True):
    f = open(file,'a')
    if verbose:
        print(str)
    f.write(str+'\n')
    f.close()
    return

# %% [markdown]
# ### The real work is done in this next loop
# - could be done in parallel except for the writing to the log file

# %%
new_zarrs = df_needed.zstore.unique()
verbose = True

zdict = {}  # construct dictionary for new rows to add to master catalog
for item,zarr in enumerate(new_zarrs):
    #if item >10:
    #    continue
    
    zbdir  = zarr_local  + zarr
    
    write_log(log_file,f"\n>>{item+1}/{num_stores}:<< local file: {zbdir}",verbose=verbose)
    
    # is zarr already in cloud?
    gsurl = 'gs://cmip6' + zarr
    contents = fs.ls(gsurl+'/.zmetadata')
    if any("zmetadata" in s for s in contents):
        write_log(log_file,'store already in cloud',verbose=verbose)
        continue

    # does zarr exist locally? 
    if os.path.isfile(zbdir+'/.zmetadata'):
        write_log(log_file,f'already exists: {zbdir}',verbose=verbose)
        continue

    gfiles,troubles,codes = get_ncfiles(zarr,df_needed,skip_sites)
    
    write_log(log_file,troubles,verbose=verbose)
    
    if len(gfiles) == 0: 
        write_log(log_file,'no files available',verbose=verbose)
        continue
    
    variable_id = zarr.split('/')[-3]
    for gfile in gfiles:   # changes file sizes!!
        command = '/usr/bin/ncatted -h -O -a missing_value\,'+variable_id+',d,, '+gfile
        os.system(command)

    # concatenate in time with mfdataset
    #print(gfiles)
    status, ds, dstr = concatenate(zarr,gfiles,codes)  

    if status == 'concatenation failure: ':
        write_log(log_file,status+dstr,verbose=verbose)
        continue
    else:
        write_log(log_file,dstr)

    try:
        del ds[variable_id].encoding['missing_value']
        ds.to_zarr(zbdir, consolidated=True, mode='w')
    except:
        ds.to_zarr(zbdir, consolidated=True, mode='w')
    

    if not os.path.isfile(zbdir+'/.zmetadata'):
        write_log(log_file,'to_zarr failure: ',verbose=verbose)
        continue
   
    vlist = get_details(ds,zbdir,zarr)
    
    # upload to cloud
    command = '/usr/bin/gsutil -m cp -r '+ zbdir[:-1] + ' ' + gsurl[:-1]
    write_log(log_file,command,verbose=verbose)
    os.system(command) 
        
    try:
        ds = xr.open_zarr(fs.get_mapper(gsurl), consolidated=True)
        zdict[item] = vlist
        write_log(log_file,f'successfully saved as {zbdir}',verbose=verbose) 
        for gfile in gfiles:
            os.system('rm -f '+ gfile)
    except:
        write_log(log_file,'store did not get saved to GCS properly',verbose=verbose)
# Out:
# >>1/777:<< local file: /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1961-r1i1p1f1/Amon/tas/gn/
# curl http://cmip.bcc.cma.cn/thredds/fileServer/cmip6_data/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1961-r1i1p1f1/Amon/tas/gn/v20191126/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1961-r1i1p1f1_gn_196101-197012.nc -o nctemp/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1961-r1i1p1f1_gn_196101-197012.nc
#
#
# /usr/bin/gsutil -m cp -r /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1961-r1i1p1f1/Amon/tas/gn gs://cmip6/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1961-r1i1p1f1/Amon/tas/gn
# successfully saved as /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1961-r1i1p1f1/Amon/tas/gn/
#
# >>2/777:<< local file: /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1961-r2i1p1f1/Amon/tas/gn/
# curl http://cmip.bcc.cma.cn/thredds/fileServer/cmip6_data/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1961-r2i1p1f1/Amon/tas/gn/v20191204/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1961-r2i1p1f1_gn_196101-197012.nc -o nctemp/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1961-r2i1p1f1_gn_196101-197012.nc
#
#
# /usr/bin/gsutil -m cp -r /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1961-r2i1p1f1/Amon/tas/gn gs://cmip6/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1961-r2i1p1f1/Amon/tas/gn
# successfully saved as /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1961-r2i1p1f1/Amon/tas/gn/
#
# >>3/777:<< local file: /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1961-r3i1p1f1/Amon/tas/gn/
# curl http://cmip.bcc.cma.cn/thredds/fileServer/cmip6_data/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1961-r3i1p1f1/Amon/tas/gn/v20191204/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1961-r3i1p1f1_gn_196101-197012.nc -o nctemp/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1961-r3i1p1f1_gn_196101-197012.nc
#
#
# /usr/bin/gsutil -m cp -r /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1961-r3i1p1f1/Amon/tas/gn gs://cmip6/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1961-r3i1p1f1/Amon/tas/gn
# successfully saved as /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1961-r3i1p1f1/Amon/tas/gn/
#
# >>4/777:<< local file: /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1961-r4i1p1f1/Amon/tas/gn/
# curl http://cmip.bcc.cma.cn/thredds/fileServer/cmip6_data/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1961-r4i1p1f1/Amon/tas/gn/v20191204/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1961-r4i1p1f1_gn_196101-197012.nc -o nctemp/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1961-r4i1p1f1_gn_196101-197012.nc
#
#
# /usr/bin/gsutil -m cp -r /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1961-r4i1p1f1/Amon/tas/gn gs://cmip6/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1961-r4i1p1f1/Amon/tas/gn
# successfully saved as /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1961-r4i1p1f1/Amon/tas/gn/
#
# >>5/777:<< local file: /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1961-r5i1p1f1/Amon/tas/gn/
# curl http://cmip.bcc.cma.cn/thredds/fileServer/cmip6_data/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1961-r5i1p1f1/Amon/tas/gn/v20191204/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1961-r5i1p1f1_gn_196101-197012.nc -o nctemp/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1961-r5i1p1f1_gn_196101-197012.nc
#
#
# /usr/bin/gsutil -m cp -r /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1961-r5i1p1f1/Amon/tas/gn gs://cmip6/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1961-r5i1p1f1/Amon/tas/gn
# successfully saved as /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1961-r5i1p1f1/Amon/tas/gn/
#
# >>6/777:<< local file: /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1961-r6i1p1f1/Amon/tas/gn/
# curl http://cmip.bcc.cma.cn/thredds/fileServer/cmip6_data/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1961-r6i1p1f1/Amon/tas/gn/v20191204/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1961-r6i1p1f1_gn_196101-197012.nc -o nctemp/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1961-r6i1p1f1_gn_196101-197012.nc
#
#
# /usr/bin/gsutil -m cp -r /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1961-r6i1p1f1/Amon/tas/gn gs://cmip6/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1961-r6i1p1f1/Amon/tas/gn
# successfully saved as /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1961-r6i1p1f1/Amon/tas/gn/
#
# >>7/777:<< local file: /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1961-r7i1p1f1/Amon/tas/gn/
# curl http://cmip.bcc.cma.cn/thredds/fileServer/cmip6_data/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1961-r7i1p1f1/Amon/tas/gn/v20191204/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1961-r7i1p1f1_gn_196101-197012.nc -o nctemp/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1961-r7i1p1f1_gn_196101-197012.nc
#
#
# /usr/bin/gsutil -m cp -r /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1961-r7i1p1f1/Amon/tas/gn gs://cmip6/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1961-r7i1p1f1/Amon/tas/gn
# successfully saved as /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1961-r7i1p1f1/Amon/tas/gn/
#
# >>8/777:<< local file: /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1961-r8i1p1f1/Amon/tas/gn/
# curl http://cmip.bcc.cma.cn/thredds/fileServer/cmip6_data/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1961-r8i1p1f1/Amon/tas/gn/v20191204/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1961-r8i1p1f1_gn_196101-197012.nc -o nctemp/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1961-r8i1p1f1_gn_196101-197012.nc
#
#
# /usr/bin/gsutil -m cp -r /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1961-r8i1p1f1/Amon/tas/gn gs://cmip6/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1961-r8i1p1f1/Amon/tas/gn
# successfully saved as /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1961-r8i1p1f1/Amon/tas/gn/
#
# >>9/777:<< local file: /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1962-r1i1p1f1/Amon/tas/gn/
# curl http://cmip.bcc.cma.cn/thredds/fileServer/cmip6_data/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1962-r1i1p1f1/Amon/tas/gn/v20191209/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1962-r1i1p1f1_gn_196201-197112.nc -o nctemp/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1962-r1i1p1f1_gn_196201-197112.nc
#
#
# /usr/bin/gsutil -m cp -r /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1962-r1i1p1f1/Amon/tas/gn gs://cmip6/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1962-r1i1p1f1/Amon/tas/gn
# successfully saved as /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1962-r1i1p1f1/Amon/tas/gn/
#
# >>10/777:<< local file: /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1962-r2i1p1f1/Amon/tas/gn/
# curl http://cmip.bcc.cma.cn/thredds/fileServer/cmip6_data/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1962-r2i1p1f1/Amon/tas/gn/v20191209/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1962-r2i1p1f1_gn_196201-197112.nc -o nctemp/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1962-r2i1p1f1_gn_196201-197112.nc
#
#
# /usr/bin/gsutil -m cp -r /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1962-r2i1p1f1/Amon/tas/gn gs://cmip6/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1962-r2i1p1f1/Amon/tas/gn
# successfully saved as /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1962-r2i1p1f1/Amon/tas/gn/
#
# >>11/777:<< local file: /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1962-r3i1p1f1/Amon/tas/gn/
# curl http://cmip.bcc.cma.cn/thredds/fileServer/cmip6_data/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1962-r3i1p1f1/Amon/tas/gn/v20191209/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1962-r3i1p1f1_gn_196201-197112.nc -o nctemp/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1962-r3i1p1f1_gn_196201-197112.nc
#
#
# /usr/bin/gsutil -m cp -r /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1962-r3i1p1f1/Amon/tas/gn gs://cmip6/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1962-r3i1p1f1/Amon/tas/gn
# successfully saved as /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1962-r3i1p1f1/Amon/tas/gn/
#
# >>12/777:<< local file: /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1962-r4i1p1f1/Amon/tas/gn/
# curl http://cmip.bcc.cma.cn/thredds/fileServer/cmip6_data/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1962-r4i1p1f1/Amon/tas/gn/v20191209/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1962-r4i1p1f1_gn_196201-197112.nc -o nctemp/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1962-r4i1p1f1_gn_196201-197112.nc
#
#
# /usr/bin/gsutil -m cp -r /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1962-r4i1p1f1/Amon/tas/gn gs://cmip6/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1962-r4i1p1f1/Amon/tas/gn
# successfully saved as /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1962-r4i1p1f1/Amon/tas/gn/
#
# >>13/777:<< local file: /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1962-r5i1p1f1/Amon/tas/gn/
# curl http://cmip.bcc.cma.cn/thredds/fileServer/cmip6_data/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1962-r5i1p1f1/Amon/tas/gn/v20191209/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1962-r5i1p1f1_gn_196201-197112.nc -o nctemp/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1962-r5i1p1f1_gn_196201-197112.nc
#
#
# /usr/bin/gsutil -m cp -r /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1962-r5i1p1f1/Amon/tas/gn gs://cmip6/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1962-r5i1p1f1/Amon/tas/gn
# successfully saved as /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1962-r5i1p1f1/Amon/tas/gn/
#
# >>14/777:<< local file: /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1962-r6i1p1f1/Amon/tas/gn/
# curl http://cmip.bcc.cma.cn/thredds/fileServer/cmip6_data/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1962-r6i1p1f1/Amon/tas/gn/v20191209/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1962-r6i1p1f1_gn_196201-197112.nc -o nctemp/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1962-r6i1p1f1_gn_196201-197112.nc
#
#
# /usr/bin/gsutil -m cp -r /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1962-r6i1p1f1/Amon/tas/gn gs://cmip6/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1962-r6i1p1f1/Amon/tas/gn
# successfully saved as /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1962-r6i1p1f1/Amon/tas/gn/
#
# >>15/777:<< local file: /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1962-r7i1p1f1/Amon/tas/gn/
# curl http://cmip.bcc.cma.cn/thredds/fileServer/cmip6_data/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1962-r7i1p1f1/Amon/tas/gn/v20191209/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1962-r7i1p1f1_gn_196201-197112.nc -o nctemp/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1962-r7i1p1f1_gn_196201-197112.nc
#
#
# /usr/bin/gsutil -m cp -r /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1962-r7i1p1f1/Amon/tas/gn gs://cmip6/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1962-r7i1p1f1/Amon/tas/gn
# successfully saved as /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1962-r7i1p1f1/Amon/tas/gn/
#
# >>16/777:<< local file: /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1962-r8i1p1f1/Amon/tas/gn/
# curl http://cmip.bcc.cma.cn/thredds/fileServer/cmip6_data/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1962-r8i1p1f1/Amon/tas/gn/v20191209/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1962-r8i1p1f1_gn_196201-197112.nc -o nctemp/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1962-r8i1p1f1_gn_196201-197112.nc
#
#
# /usr/bin/gsutil -m cp -r /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1962-r8i1p1f1/Amon/tas/gn gs://cmip6/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1962-r8i1p1f1/Amon/tas/gn
# successfully saved as /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1962-r8i1p1f1/Amon/tas/gn/
#
# >>17/777:<< local file: /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1963-r1i1p1f1/Amon/tas/gn/
# curl http://cmip.bcc.cma.cn/thredds/fileServer/cmip6_data/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1963-r1i1p1f1/Amon/tas/gn/v20191213/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1963-r1i1p1f1_gn_196301-197212.nc -o nctemp/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1963-r1i1p1f1_gn_196301-197212.nc
#
#
# /usr/bin/gsutil -m cp -r /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1963-r1i1p1f1/Amon/tas/gn gs://cmip6/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1963-r1i1p1f1/Amon/tas/gn
# successfully saved as /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1963-r1i1p1f1/Amon/tas/gn/
#
# >>18/777:<< local file: /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1963-r2i1p1f1/Amon/tas/gn/
# curl http://cmip.bcc.cma.cn/thredds/fileServer/cmip6_data/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1963-r2i1p1f1/Amon/tas/gn/v20191213/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1963-r2i1p1f1_gn_196301-197212.nc -o nctemp/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1963-r2i1p1f1_gn_196301-197212.nc
#
#
# /usr/bin/gsutil -m cp -r /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1963-r2i1p1f1/Amon/tas/gn gs://cmip6/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1963-r2i1p1f1/Amon/tas/gn
# successfully saved as /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1963-r2i1p1f1/Amon/tas/gn/
#
# >>19/777:<< local file: /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1963-r3i1p1f1/Amon/tas/gn/
# curl http://cmip.bcc.cma.cn/thredds/fileServer/cmip6_data/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1963-r3i1p1f1/Amon/tas/gn/v20191213/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1963-r3i1p1f1_gn_196301-197212.nc -o nctemp/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1963-r3i1p1f1_gn_196301-197212.nc
#
#
# /usr/bin/gsutil -m cp -r /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1963-r3i1p1f1/Amon/tas/gn gs://cmip6/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1963-r3i1p1f1/Amon/tas/gn
# successfully saved as /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1963-r3i1p1f1/Amon/tas/gn/
#
# >>20/777:<< local file: /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1963-r4i1p1f1/Amon/tas/gn/
# curl http://cmip.bcc.cma.cn/thredds/fileServer/cmip6_data/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1963-r4i1p1f1/Amon/tas/gn/v20191213/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1963-r4i1p1f1_gn_196301-197212.nc -o nctemp/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1963-r4i1p1f1_gn_196301-197212.nc
#
#
# /usr/bin/gsutil -m cp -r /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1963-r4i1p1f1/Amon/tas/gn gs://cmip6/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1963-r4i1p1f1/Amon/tas/gn
# successfully saved as /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1963-r4i1p1f1/Amon/tas/gn/
#
# >>21/777:<< local file: /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1963-r5i1p1f1/Amon/tas/gn/
# curl http://cmip.bcc.cma.cn/thredds/fileServer/cmip6_data/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1963-r5i1p1f1/Amon/tas/gn/v20191213/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1963-r5i1p1f1_gn_196301-197212.nc -o nctemp/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1963-r5i1p1f1_gn_196301-197212.nc
#
#
# /usr/bin/gsutil -m cp -r /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1963-r5i1p1f1/Amon/tas/gn gs://cmip6/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1963-r5i1p1f1/Amon/tas/gn
# successfully saved as /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1963-r5i1p1f1/Amon/tas/gn/
#
# >>22/777:<< local file: /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1963-r6i1p1f1/Amon/tas/gn/
# curl http://cmip.bcc.cma.cn/thredds/fileServer/cmip6_data/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1963-r6i1p1f1/Amon/tas/gn/v20191213/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1963-r6i1p1f1_gn_196301-197212.nc -o nctemp/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1963-r6i1p1f1_gn_196301-197212.nc
#
#
# /usr/bin/gsutil -m cp -r /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1963-r6i1p1f1/Amon/tas/gn gs://cmip6/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1963-r6i1p1f1/Amon/tas/gn
# successfully saved as /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1963-r6i1p1f1/Amon/tas/gn/
#
# >>23/777:<< local file: /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1963-r7i1p1f1/Amon/tas/gn/
# curl http://cmip.bcc.cma.cn/thredds/fileServer/cmip6_data/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1963-r7i1p1f1/Amon/tas/gn/v20191213/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1963-r7i1p1f1_gn_196301-197212.nc -o nctemp/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1963-r7i1p1f1_gn_196301-197212.nc
#
#
# /usr/bin/gsutil -m cp -r /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1963-r7i1p1f1/Amon/tas/gn gs://cmip6/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1963-r7i1p1f1/Amon/tas/gn
# successfully saved as /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1963-r7i1p1f1/Amon/tas/gn/
#
# >>24/777:<< local file: /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1963-r8i1p1f1/Amon/tas/gn/
# curl http://cmip.bcc.cma.cn/thredds/fileServer/cmip6_data/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1963-r8i1p1f1/Amon/tas/gn/v20191213/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1963-r8i1p1f1_gn_196301-197212.nc -o nctemp/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1963-r8i1p1f1_gn_196301-197212.nc
#
#
# /usr/bin/gsutil -m cp -r /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1963-r8i1p1f1/Amon/tas/gn gs://cmip6/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1963-r8i1p1f1/Amon/tas/gn
# successfully saved as /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1963-r8i1p1f1/Amon/tas/gn/
#
# >>25/777:<< local file: /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1964-r1i1p1f1/Amon/tas/gn/
# curl http://cmip.bcc.cma.cn/thredds/fileServer/cmip6_data/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1964-r1i1p1f1/Amon/tas/gn/v20191213/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1964-r1i1p1f1_gn_196401-197312.nc -o nctemp/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1964-r1i1p1f1_gn_196401-197312.nc
#
#
# /usr/bin/gsutil -m cp -r /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1964-r1i1p1f1/Amon/tas/gn gs://cmip6/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1964-r1i1p1f1/Amon/tas/gn
# successfully saved as /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1964-r1i1p1f1/Amon/tas/gn/
#
# >>26/777:<< local file: /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1964-r2i1p1f1/Amon/tas/gn/
# curl http://cmip.bcc.cma.cn/thredds/fileServer/cmip6_data/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1964-r2i1p1f1/Amon/tas/gn/v20191213/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1964-r2i1p1f1_gn_196401-197312.nc -o nctemp/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1964-r2i1p1f1_gn_196401-197312.nc
#
#
# /usr/bin/gsutil -m cp -r /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1964-r2i1p1f1/Amon/tas/gn gs://cmip6/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1964-r2i1p1f1/Amon/tas/gn
# successfully saved as /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1964-r2i1p1f1/Amon/tas/gn/
#
# >>27/777:<< local file: /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1964-r3i1p1f1/Amon/tas/gn/
# curl http://cmip.bcc.cma.cn/thredds/fileServer/cmip6_data/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1964-r3i1p1f1/Amon/tas/gn/v20191213/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1964-r3i1p1f1_gn_196401-197312.nc -o nctemp/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1964-r3i1p1f1_gn_196401-197312.nc
#
#
# /usr/bin/gsutil -m cp -r /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1964-r3i1p1f1/Amon/tas/gn gs://cmip6/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1964-r3i1p1f1/Amon/tas/gn
# successfully saved as /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1964-r3i1p1f1/Amon/tas/gn/
#
# >>28/777:<< local file: /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1964-r4i1p1f1/Amon/tas/gn/
# curl http://cmip.bcc.cma.cn/thredds/fileServer/cmip6_data/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1964-r4i1p1f1/Amon/tas/gn/v20191213/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1964-r4i1p1f1_gn_196401-197312.nc -o nctemp/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1964-r4i1p1f1_gn_196401-197312.nc
#
#
# /usr/bin/gsutil -m cp -r /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1964-r4i1p1f1/Amon/tas/gn gs://cmip6/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1964-r4i1p1f1/Amon/tas/gn
# successfully saved as /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1964-r4i1p1f1/Amon/tas/gn/
#
# >>29/777:<< local file: /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1964-r5i1p1f1/Amon/tas/gn/
# curl http://cmip.bcc.cma.cn/thredds/fileServer/cmip6_data/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1964-r5i1p1f1/Amon/tas/gn/v20191213/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1964-r5i1p1f1_gn_196401-197312.nc -o nctemp/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1964-r5i1p1f1_gn_196401-197312.nc
#
#
# /usr/bin/gsutil -m cp -r /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1964-r5i1p1f1/Amon/tas/gn gs://cmip6/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1964-r5i1p1f1/Amon/tas/gn
# successfully saved as /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1964-r5i1p1f1/Amon/tas/gn/
#
# >>30/777:<< local file: /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1964-r6i1p1f1/Amon/tas/gn/
# curl http://cmip.bcc.cma.cn/thredds/fileServer/cmip6_data/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1964-r6i1p1f1/Amon/tas/gn/v20191213/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1964-r6i1p1f1_gn_196401-197312.nc -o nctemp/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1964-r6i1p1f1_gn_196401-197312.nc
#
#
# /usr/bin/gsutil -m cp -r /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1964-r6i1p1f1/Amon/tas/gn gs://cmip6/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1964-r6i1p1f1/Amon/tas/gn
# successfully saved as /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1964-r6i1p1f1/Amon/tas/gn/
#
# >>31/777:<< local file: /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1964-r7i1p1f1/Amon/tas/gn/
# curl http://cmip.bcc.cma.cn/thredds/fileServer/cmip6_data/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1964-r7i1p1f1/Amon/tas/gn/v20191213/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1964-r7i1p1f1_gn_196401-197312.nc -o nctemp/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1964-r7i1p1f1_gn_196401-197312.nc
#
#
# /usr/bin/gsutil -m cp -r /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1964-r7i1p1f1/Amon/tas/gn gs://cmip6/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1964-r7i1p1f1/Amon/tas/gn
# successfully saved as /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1964-r7i1p1f1/Amon/tas/gn/
#
# >>32/777:<< local file: /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1964-r8i1p1f1/Amon/tas/gn/
# curl http://cmip.bcc.cma.cn/thredds/fileServer/cmip6_data/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1964-r8i1p1f1/Amon/tas/gn/v20191213/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1964-r8i1p1f1_gn_196401-197312.nc -o nctemp/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1964-r8i1p1f1_gn_196401-197312.nc
#
#
# /usr/bin/gsutil -m cp -r /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1964-r8i1p1f1/Amon/tas/gn gs://cmip6/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1964-r8i1p1f1/Amon/tas/gn
# successfully saved as /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1964-r8i1p1f1/Amon/tas/gn/
#
# >>33/777:<< local file: /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1965-r1i1p1f1/Amon/tas/gn/
# curl http://cmip.bcc.cma.cn/thredds/fileServer/cmip6_data/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1965-r1i1p1f1/Amon/tas/gn/v20191213/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1965-r1i1p1f1_gn_196501-197412.nc -o nctemp/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1965-r1i1p1f1_gn_196501-197412.nc
#
#
# /usr/bin/gsutil -m cp -r /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1965-r1i1p1f1/Amon/tas/gn gs://cmip6/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1965-r1i1p1f1/Amon/tas/gn
# successfully saved as /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1965-r1i1p1f1/Amon/tas/gn/
#
# >>34/777:<< local file: /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1965-r2i1p1f1/Amon/tas/gn/
# curl http://cmip.bcc.cma.cn/thredds/fileServer/cmip6_data/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1965-r2i1p1f1/Amon/tas/gn/v20191213/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1965-r2i1p1f1_gn_196501-197412.nc -o nctemp/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1965-r2i1p1f1_gn_196501-197412.nc
#
#
# /usr/bin/gsutil -m cp -r /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1965-r2i1p1f1/Amon/tas/gn gs://cmip6/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1965-r2i1p1f1/Amon/tas/gn
# successfully saved as /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1965-r2i1p1f1/Amon/tas/gn/
#
# >>35/777:<< local file: /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1965-r3i1p1f1/Amon/tas/gn/
# curl http://cmip.bcc.cma.cn/thredds/fileServer/cmip6_data/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1965-r3i1p1f1/Amon/tas/gn/v20191213/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1965-r3i1p1f1_gn_196501-197412.nc -o nctemp/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1965-r3i1p1f1_gn_196501-197412.nc
#
#
# /usr/bin/gsutil -m cp -r /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1965-r3i1p1f1/Amon/tas/gn gs://cmip6/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1965-r3i1p1f1/Amon/tas/gn
# successfully saved as /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1965-r3i1p1f1/Amon/tas/gn/
#
# >>36/777:<< local file: /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1965-r4i1p1f1/Amon/tas/gn/
# curl http://cmip.bcc.cma.cn/thredds/fileServer/cmip6_data/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1965-r4i1p1f1/Amon/tas/gn/v20191213/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1965-r4i1p1f1_gn_196501-197412.nc -o nctemp/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1965-r4i1p1f1_gn_196501-197412.nc
#
#
# /usr/bin/gsutil -m cp -r /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1965-r4i1p1f1/Amon/tas/gn gs://cmip6/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1965-r4i1p1f1/Amon/tas/gn
# successfully saved as /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1965-r4i1p1f1/Amon/tas/gn/
#
# >>37/777:<< local file: /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1965-r5i1p1f1/Amon/tas/gn/
# curl http://cmip.bcc.cma.cn/thredds/fileServer/cmip6_data/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1965-r5i1p1f1/Amon/tas/gn/v20191213/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1965-r5i1p1f1_gn_196501-197412.nc -o nctemp/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1965-r5i1p1f1_gn_196501-197412.nc
#
#
# /usr/bin/gsutil -m cp -r /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1965-r5i1p1f1/Amon/tas/gn gs://cmip6/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1965-r5i1p1f1/Amon/tas/gn
# successfully saved as /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1965-r5i1p1f1/Amon/tas/gn/
#
# >>38/777:<< local file: /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1965-r6i1p1f1/Amon/tas/gn/
# curl http://cmip.bcc.cma.cn/thredds/fileServer/cmip6_data/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1965-r6i1p1f1/Amon/tas/gn/v20191213/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1965-r6i1p1f1_gn_196501-197412.nc -o nctemp/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1965-r6i1p1f1_gn_196501-197412.nc
#
#
# /usr/bin/gsutil -m cp -r /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1965-r6i1p1f1/Amon/tas/gn gs://cmip6/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1965-r6i1p1f1/Amon/tas/gn
# successfully saved as /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1965-r6i1p1f1/Amon/tas/gn/
#
# >>39/777:<< local file: /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1965-r7i1p1f1/Amon/tas/gn/
# curl http://cmip.bcc.cma.cn/thredds/fileServer/cmip6_data/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1965-r7i1p1f1/Amon/tas/gn/v20191213/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1965-r7i1p1f1_gn_196501-197412.nc -o nctemp/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1965-r7i1p1f1_gn_196501-197412.nc
#
#
# /usr/bin/gsutil -m cp -r /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1965-r7i1p1f1/Amon/tas/gn gs://cmip6/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1965-r7i1p1f1/Amon/tas/gn
# successfully saved as /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1965-r7i1p1f1/Amon/tas/gn/
#
# >>40/777:<< local file: /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1965-r8i1p1f1/Amon/tas/gn/
# curl http://cmip.bcc.cma.cn/thredds/fileServer/cmip6_data/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1965-r8i1p1f1/Amon/tas/gn/v20191213/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1965-r8i1p1f1_gn_196501-197412.nc -o nctemp/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1965-r8i1p1f1_gn_196501-197412.nc
#
#
# /usr/bin/gsutil -m cp -r /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1965-r8i1p1f1/Amon/tas/gn gs://cmip6/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1965-r8i1p1f1/Amon/tas/gn
# successfully saved as /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1965-r8i1p1f1/Amon/tas/gn/
#
# >>41/777:<< local file: /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1966-r1i1p1f1/Amon/tas/gn/
# curl http://cmip.bcc.cma.cn/thredds/fileServer/cmip6_data/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1966-r1i1p1f1/Amon/tas/gn/v20191213/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1966-r1i1p1f1_gn_196601-197512.nc -o nctemp/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1966-r1i1p1f1_gn_196601-197512.nc
#
#
# /usr/bin/gsutil -m cp -r /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1966-r1i1p1f1/Amon/tas/gn gs://cmip6/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1966-r1i1p1f1/Amon/tas/gn
# successfully saved as /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1966-r1i1p1f1/Amon/tas/gn/
#
# >>42/777:<< local file: /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1966-r2i1p1f1/Amon/tas/gn/
# curl http://cmip.bcc.cma.cn/thredds/fileServer/cmip6_data/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1966-r2i1p1f1/Amon/tas/gn/v20191213/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1966-r2i1p1f1_gn_196601-197512.nc -o nctemp/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1966-r2i1p1f1_gn_196601-197512.nc
#
#
# /usr/bin/gsutil -m cp -r /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1966-r2i1p1f1/Amon/tas/gn gs://cmip6/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1966-r2i1p1f1/Amon/tas/gn
# successfully saved as /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1966-r2i1p1f1/Amon/tas/gn/
#
# >>43/777:<< local file: /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1966-r3i1p1f1/Amon/tas/gn/
# curl http://cmip.bcc.cma.cn/thredds/fileServer/cmip6_data/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1966-r3i1p1f1/Amon/tas/gn/v20191213/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1966-r3i1p1f1_gn_196601-197512.nc -o nctemp/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1966-r3i1p1f1_gn_196601-197512.nc
#
#
# /usr/bin/gsutil -m cp -r /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1966-r3i1p1f1/Amon/tas/gn gs://cmip6/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1966-r3i1p1f1/Amon/tas/gn
# successfully saved as /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1966-r3i1p1f1/Amon/tas/gn/
#
# >>44/777:<< local file: /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1966-r4i1p1f1/Amon/tas/gn/
# curl http://cmip.bcc.cma.cn/thredds/fileServer/cmip6_data/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1966-r4i1p1f1/Amon/tas/gn/v20191213/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1966-r4i1p1f1_gn_196601-197512.nc -o nctemp/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1966-r4i1p1f1_gn_196601-197512.nc
#
#
# /usr/bin/gsutil -m cp -r /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1966-r4i1p1f1/Amon/tas/gn gs://cmip6/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1966-r4i1p1f1/Amon/tas/gn
# successfully saved as /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1966-r4i1p1f1/Amon/tas/gn/
#
# >>45/777:<< local file: /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1966-r5i1p1f1/Amon/tas/gn/
# curl http://cmip.bcc.cma.cn/thredds/fileServer/cmip6_data/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1966-r5i1p1f1/Amon/tas/gn/v20191213/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1966-r5i1p1f1_gn_196601-197512.nc -o nctemp/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1966-r5i1p1f1_gn_196601-197512.nc
#
#
# /usr/bin/gsutil -m cp -r /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1966-r5i1p1f1/Amon/tas/gn gs://cmip6/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1966-r5i1p1f1/Amon/tas/gn
# successfully saved as /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1966-r5i1p1f1/Amon/tas/gn/
#
# >>46/777:<< local file: /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1966-r6i1p1f1/Amon/tas/gn/
# curl http://cmip.bcc.cma.cn/thredds/fileServer/cmip6_data/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1966-r6i1p1f1/Amon/tas/gn/v20191213/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1966-r6i1p1f1_gn_196601-197512.nc -o nctemp/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1966-r6i1p1f1_gn_196601-197512.nc
#
#
# /usr/bin/gsutil -m cp -r /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1966-r6i1p1f1/Amon/tas/gn gs://cmip6/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1966-r6i1p1f1/Amon/tas/gn
# successfully saved as /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1966-r6i1p1f1/Amon/tas/gn/
#
# >>47/777:<< local file: /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1966-r7i1p1f1/Amon/tas/gn/
# curl http://cmip.bcc.cma.cn/thredds/fileServer/cmip6_data/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1966-r7i1p1f1/Amon/tas/gn/v20191213/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1966-r7i1p1f1_gn_196601-197512.nc -o nctemp/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1966-r7i1p1f1_gn_196601-197512.nc
#
#
# /usr/bin/gsutil -m cp -r /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1966-r7i1p1f1/Amon/tas/gn gs://cmip6/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1966-r7i1p1f1/Amon/tas/gn
# successfully saved as /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1966-r7i1p1f1/Amon/tas/gn/
#
# >>48/777:<< local file: /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1966-r8i1p1f1/Amon/tas/gn/
# curl http://cmip.bcc.cma.cn/thredds/fileServer/cmip6_data/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1966-r8i1p1f1/Amon/tas/gn/v20191213/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1966-r8i1p1f1_gn_196601-197512.nc -o nctemp/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1966-r8i1p1f1_gn_196601-197512.nc
#
#
# /usr/bin/gsutil -m cp -r /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1966-r8i1p1f1/Amon/tas/gn gs://cmip6/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1966-r8i1p1f1/Amon/tas/gn
# successfully saved as /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1966-r8i1p1f1/Amon/tas/gn/
#
# >>49/777:<< local file: /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1967-r1i1p1f1/Amon/tas/gn/
# curl http://cmip.bcc.cma.cn/thredds/fileServer/cmip6_data/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1967-r1i1p1f1/Amon/tas/gn/v20191213/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1967-r1i1p1f1_gn_196701-197612.nc -o nctemp/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1967-r1i1p1f1_gn_196701-197612.nc
#
#
# /usr/bin/gsutil -m cp -r /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1967-r1i1p1f1/Amon/tas/gn gs://cmip6/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1967-r1i1p1f1/Amon/tas/gn
# successfully saved as /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1967-r1i1p1f1/Amon/tas/gn/
#
# >>50/777:<< local file: /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1967-r2i1p1f1/Amon/tas/gn/
# curl http://cmip.bcc.cma.cn/thredds/fileServer/cmip6_data/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1967-r2i1p1f1/Amon/tas/gn/v20191213/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1967-r2i1p1f1_gn_196701-197612.nc -o nctemp/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1967-r2i1p1f1_gn_196701-197612.nc
#
#
# /usr/bin/gsutil -m cp -r /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1967-r2i1p1f1/Amon/tas/gn gs://cmip6/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1967-r2i1p1f1/Amon/tas/gn
# successfully saved as /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1967-r2i1p1f1/Amon/tas/gn/
#
# >>51/777:<< local file: /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1967-r3i1p1f1/Amon/tas/gn/
# curl http://cmip.bcc.cma.cn/thredds/fileServer/cmip6_data/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1967-r3i1p1f1/Amon/tas/gn/v20191213/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1967-r3i1p1f1_gn_196701-197612.nc -o nctemp/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1967-r3i1p1f1_gn_196701-197612.nc
#
#
# /usr/bin/gsutil -m cp -r /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1967-r3i1p1f1/Amon/tas/gn gs://cmip6/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1967-r3i1p1f1/Amon/tas/gn
# successfully saved as /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1967-r3i1p1f1/Amon/tas/gn/
#
# >>52/777:<< local file: /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1967-r4i1p1f1/Amon/tas/gn/
# curl http://cmip.bcc.cma.cn/thredds/fileServer/cmip6_data/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1967-r4i1p1f1/Amon/tas/gn/v20191213/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1967-r4i1p1f1_gn_196701-197612.nc -o nctemp/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1967-r4i1p1f1_gn_196701-197612.nc
#
#
# /usr/bin/gsutil -m cp -r /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1967-r4i1p1f1/Amon/tas/gn gs://cmip6/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1967-r4i1p1f1/Amon/tas/gn
# successfully saved as /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1967-r4i1p1f1/Amon/tas/gn/
#
# >>53/777:<< local file: /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1967-r5i1p1f1/Amon/tas/gn/
# curl http://cmip.bcc.cma.cn/thredds/fileServer/cmip6_data/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1967-r5i1p1f1/Amon/tas/gn/v20191213/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1967-r5i1p1f1_gn_196701-197612.nc -o nctemp/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1967-r5i1p1f1_gn_196701-197612.nc
#
#
# /usr/bin/gsutil -m cp -r /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1967-r5i1p1f1/Amon/tas/gn gs://cmip6/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1967-r5i1p1f1/Amon/tas/gn
# successfully saved as /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1967-r5i1p1f1/Amon/tas/gn/
#
# >>54/777:<< local file: /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1967-r6i1p1f1/Amon/tas/gn/
# curl http://cmip.bcc.cma.cn/thredds/fileServer/cmip6_data/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1967-r6i1p1f1/Amon/tas/gn/v20191213/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1967-r6i1p1f1_gn_196701-197612.nc -o nctemp/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1967-r6i1p1f1_gn_196701-197612.nc
#
#
# /usr/bin/gsutil -m cp -r /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1967-r6i1p1f1/Amon/tas/gn gs://cmip6/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1967-r6i1p1f1/Amon/tas/gn
# successfully saved as /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1967-r6i1p1f1/Amon/tas/gn/
#
# >>55/777:<< local file: /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1967-r7i1p1f1/Amon/tas/gn/
# curl http://cmip.bcc.cma.cn/thredds/fileServer/cmip6_data/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1967-r7i1p1f1/Amon/tas/gn/v20191213/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1967-r7i1p1f1_gn_196701-197612.nc -o nctemp/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1967-r7i1p1f1_gn_196701-197612.nc
#
#
# /usr/bin/gsutil -m cp -r /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1967-r7i1p1f1/Amon/tas/gn gs://cmip6/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1967-r7i1p1f1/Amon/tas/gn
# successfully saved as /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1967-r7i1p1f1/Amon/tas/gn/
#
# >>56/777:<< local file: /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1967-r8i1p1f1/Amon/tas/gn/
# curl http://cmip.bcc.cma.cn/thredds/fileServer/cmip6_data/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1967-r8i1p1f1/Amon/tas/gn/v20191213/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1967-r8i1p1f1_gn_196701-197612.nc -o nctemp/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1967-r8i1p1f1_gn_196701-197612.nc
#
#
# /usr/bin/gsutil -m cp -r /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1967-r8i1p1f1/Amon/tas/gn gs://cmip6/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1967-r8i1p1f1/Amon/tas/gn
# successfully saved as /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1967-r8i1p1f1/Amon/tas/gn/
#
# >>57/777:<< local file: /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1968-r1i1p1f1/Amon/tas/gn/
# curl http://cmip.bcc.cma.cn/thredds/fileServer/cmip6_data/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1968-r1i1p1f1/Amon/tas/gn/v20191213/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1968-r1i1p1f1_gn_196801-197712.nc -o nctemp/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1968-r1i1p1f1_gn_196801-197712.nc
#
#
# /usr/bin/gsutil -m cp -r /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1968-r1i1p1f1/Amon/tas/gn gs://cmip6/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1968-r1i1p1f1/Amon/tas/gn
# successfully saved as /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1968-r1i1p1f1/Amon/tas/gn/
#
# >>58/777:<< local file: /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1968-r2i1p1f1/Amon/tas/gn/
# curl http://cmip.bcc.cma.cn/thredds/fileServer/cmip6_data/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1968-r2i1p1f1/Amon/tas/gn/v20191213/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1968-r2i1p1f1_gn_196801-197712.nc -o nctemp/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1968-r2i1p1f1_gn_196801-197712.nc
#
#
# /usr/bin/gsutil -m cp -r /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1968-r2i1p1f1/Amon/tas/gn gs://cmip6/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1968-r2i1p1f1/Amon/tas/gn
# successfully saved as /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1968-r2i1p1f1/Amon/tas/gn/
#
# >>59/777:<< local file: /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1968-r3i1p1f1/Amon/tas/gn/
# curl http://cmip.bcc.cma.cn/thredds/fileServer/cmip6_data/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1968-r3i1p1f1/Amon/tas/gn/v20191213/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1968-r3i1p1f1_gn_196801-197712.nc -o nctemp/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1968-r3i1p1f1_gn_196801-197712.nc
#
#
# /usr/bin/gsutil -m cp -r /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1968-r3i1p1f1/Amon/tas/gn gs://cmip6/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1968-r3i1p1f1/Amon/tas/gn
# successfully saved as /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1968-r3i1p1f1/Amon/tas/gn/
#
# >>60/777:<< local file: /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1968-r4i1p1f1/Amon/tas/gn/
# curl http://cmip.bcc.cma.cn/thredds/fileServer/cmip6_data/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1968-r4i1p1f1/Amon/tas/gn/v20191213/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1968-r4i1p1f1_gn_196801-197712.nc -o nctemp/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1968-r4i1p1f1_gn_196801-197712.nc
#
#
# /usr/bin/gsutil -m cp -r /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1968-r4i1p1f1/Amon/tas/gn gs://cmip6/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1968-r4i1p1f1/Amon/tas/gn
# successfully saved as /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1968-r4i1p1f1/Amon/tas/gn/
#
# >>61/777:<< local file: /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1968-r5i1p1f1/Amon/tas/gn/
# curl http://cmip.bcc.cma.cn/thredds/fileServer/cmip6_data/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1968-r5i1p1f1/Amon/tas/gn/v20191213/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1968-r5i1p1f1_gn_196801-197712.nc -o nctemp/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1968-r5i1p1f1_gn_196801-197712.nc
#
#
# /usr/bin/gsutil -m cp -r /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1968-r5i1p1f1/Amon/tas/gn gs://cmip6/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1968-r5i1p1f1/Amon/tas/gn
# successfully saved as /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1968-r5i1p1f1/Amon/tas/gn/
#
# >>62/777:<< local file: /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1968-r6i1p1f1/Amon/tas/gn/
# curl http://cmip.bcc.cma.cn/thredds/fileServer/cmip6_data/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1968-r6i1p1f1/Amon/tas/gn/v20191213/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1968-r6i1p1f1_gn_196801-197712.nc -o nctemp/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1968-r6i1p1f1_gn_196801-197712.nc
#
#
# /usr/bin/gsutil -m cp -r /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1968-r6i1p1f1/Amon/tas/gn gs://cmip6/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1968-r6i1p1f1/Amon/tas/gn
# successfully saved as /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1968-r6i1p1f1/Amon/tas/gn/
#
# >>63/777:<< local file: /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1968-r7i1p1f1/Amon/tas/gn/
# curl http://cmip.bcc.cma.cn/thredds/fileServer/cmip6_data/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1968-r7i1p1f1/Amon/tas/gn/v20191213/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1968-r7i1p1f1_gn_196801-197712.nc -o nctemp/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1968-r7i1p1f1_gn_196801-197712.nc
#
#
# /usr/bin/gsutil -m cp -r /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1968-r7i1p1f1/Amon/tas/gn gs://cmip6/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1968-r7i1p1f1/Amon/tas/gn
# successfully saved as /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1968-r7i1p1f1/Amon/tas/gn/
#
# >>64/777:<< local file: /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1968-r8i1p1f1/Amon/tas/gn/
# curl http://cmip.bcc.cma.cn/thredds/fileServer/cmip6_data/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1968-r8i1p1f1/Amon/tas/gn/v20191213/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1968-r8i1p1f1_gn_196801-197712.nc -o nctemp/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1968-r8i1p1f1_gn_196801-197712.nc
#
#
# /usr/bin/gsutil -m cp -r /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1968-r8i1p1f1/Amon/tas/gn gs://cmip6/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1968-r8i1p1f1/Amon/tas/gn
# successfully saved as /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1968-r8i1p1f1/Amon/tas/gn/
#
# >>65/777:<< local file: /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1969-r1i1p1f1/Amon/tas/gn/
# curl http://cmip.bcc.cma.cn/thredds/fileServer/cmip6_data/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1969-r1i1p1f1/Amon/tas/gn/v20191213/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1969-r1i1p1f1_gn_196901-197812.nc -o nctemp/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1969-r1i1p1f1_gn_196901-197812.nc
#
#
# /usr/bin/gsutil -m cp -r /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1969-r1i1p1f1/Amon/tas/gn gs://cmip6/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1969-r1i1p1f1/Amon/tas/gn
# successfully saved as /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1969-r1i1p1f1/Amon/tas/gn/
#
# >>66/777:<< local file: /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1969-r2i1p1f1/Amon/tas/gn/
# curl http://cmip.bcc.cma.cn/thredds/fileServer/cmip6_data/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1969-r2i1p1f1/Amon/tas/gn/v20191213/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1969-r2i1p1f1_gn_196901-197812.nc -o nctemp/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1969-r2i1p1f1_gn_196901-197812.nc
#
#
# /usr/bin/gsutil -m cp -r /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1969-r2i1p1f1/Amon/tas/gn gs://cmip6/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1969-r2i1p1f1/Amon/tas/gn
# successfully saved as /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1969-r2i1p1f1/Amon/tas/gn/
#
# >>67/777:<< local file: /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1969-r3i1p1f1/Amon/tas/gn/
# curl http://cmip.bcc.cma.cn/thredds/fileServer/cmip6_data/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1969-r3i1p1f1/Amon/tas/gn/v20191213/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1969-r3i1p1f1_gn_196901-197812.nc -o nctemp/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1969-r3i1p1f1_gn_196901-197812.nc
#
#
# /usr/bin/gsutil -m cp -r /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1969-r3i1p1f1/Amon/tas/gn gs://cmip6/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1969-r3i1p1f1/Amon/tas/gn
# successfully saved as /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1969-r3i1p1f1/Amon/tas/gn/
#
# >>68/777:<< local file: /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1969-r4i1p1f1/Amon/tas/gn/
# curl http://cmip.bcc.cma.cn/thredds/fileServer/cmip6_data/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1969-r4i1p1f1/Amon/tas/gn/v20191213/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1969-r4i1p1f1_gn_196901-197812.nc -o nctemp/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1969-r4i1p1f1_gn_196901-197812.nc
#
#
# /usr/bin/gsutil -m cp -r /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1969-r4i1p1f1/Amon/tas/gn gs://cmip6/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1969-r4i1p1f1/Amon/tas/gn
# successfully saved as /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1969-r4i1p1f1/Amon/tas/gn/
#
# >>69/777:<< local file: /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1969-r5i1p1f1/Amon/tas/gn/
# curl http://cmip.bcc.cma.cn/thredds/fileServer/cmip6_data/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1969-r5i1p1f1/Amon/tas/gn/v20191213/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1969-r5i1p1f1_gn_196901-197812.nc -o nctemp/tas_Amon_BCC-CSM2-MR_dcppA-hindcast_s1969-r5i1p1f1_gn_196901-197812.nc
#
#
# /usr/bin/gsutil -m cp -r /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1969-r5i1p1f1/Amon/tas/gn gs://cmip6/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1969-r5i1p1f1/Amon/tas/gn
# successfully saved as /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1969-r5i1p1f1/Amon/tas/gn/
#
# >>70/777:<< local file: /h62/naomi/zarr-minimal/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1969-r6i1p1f1/Amon/tas/gn/
# ...
# already exists: /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2014-r7i2p1f1/Amon/tas/gn/
#
# >>736/777:<< local file: /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2014-r8i1p1f1/Amon/tas/gn/
# already exists: /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2014-r8i1p1f1/Amon/tas/gn/
#
# >>737/777:<< local file: /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2014-r9i1p1f1/Amon/tas/gn/
# already exists: /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2014-r9i1p1f1/Amon/tas/gn/
#
# >>738/777:<< local file: /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2015-r10i2p1f1/Amon/tas/gn/
# curl http://esgf-data1.llnl.gov/thredds/fileServer/css03_data/CMIP6/DCPP/NCC/NorCPM1/dcppA-hindcast/s2015-r10i2p1f1/Amon/tas/gn/v20190914/tas_Amon_NorCPM1_dcppA-hindcast_s2015-r10i2p1f1_gn_201510-202512.nc -o nctemp/tas_Amon_NorCPM1_dcppA-hindcast_s2015-r10i2p1f1_gn_201510-202512.nc
#
#
# /usr/bin/gsutil -m cp -r /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2015-r10i2p1f1/Amon/tas/gn gs://cmip6/DCPP/NCC/NorCPM1/dcppA-hindcast/s2015-r10i2p1f1/Amon/tas/gn
# successfully saved as /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2015-r10i2p1f1/Amon/tas/gn/
#
# >>739/777:<< local file: /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2015-r1i2p1f1/Amon/tas/gn/
# already exists: /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2015-r1i2p1f1/Amon/tas/gn/
#
# >>740/777:<< local file: /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2015-r3i1p1f1/Amon/tas/gn/
# already exists: /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2015-r3i1p1f1/Amon/tas/gn/
#
# >>741/777:<< local file: /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2015-r4i2p1f1/Amon/tas/gn/
# curl http://esgf-data1.llnl.gov/thredds/fileServer/css03_data/CMIP6/DCPP/NCC/NorCPM1/dcppA-hindcast/s2015-r4i2p1f1/Amon/tas/gn/v20190914/tas_Amon_NorCPM1_dcppA-hindcast_s2015-r4i2p1f1_gn_201510-202512.nc -o nctemp/tas_Amon_NorCPM1_dcppA-hindcast_s2015-r4i2p1f1_gn_201510-202512.nc
#
#
# /usr/bin/gsutil -m cp -r /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2015-r4i2p1f1/Amon/tas/gn gs://cmip6/DCPP/NCC/NorCPM1/dcppA-hindcast/s2015-r4i2p1f1/Amon/tas/gn
# successfully saved as /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2015-r4i2p1f1/Amon/tas/gn/
#
# >>742/777:<< local file: /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2015-r5i2p1f1/Amon/tas/gn/
# already exists: /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2015-r5i2p1f1/Amon/tas/gn/
#
# >>743/777:<< local file: /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2015-r6i2p1f1/Amon/tas/gn/
# already exists: /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2015-r6i2p1f1/Amon/tas/gn/
#
# >>744/777:<< local file: /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2015-r7i1p1f1/Amon/tas/gn/
# already exists: /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2015-r7i1p1f1/Amon/tas/gn/
#
# >>745/777:<< local file: /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2015-r7i2p1f1/Amon/tas/gn/
# already exists: /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2015-r7i2p1f1/Amon/tas/gn/
#
# >>746/777:<< local file: /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2015-r8i2p1f1/Amon/tas/gn/
# already exists: /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2015-r8i2p1f1/Amon/tas/gn/
#
# >>747/777:<< local file: /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2015-r9i1p1f1/Amon/tas/gn/
# already exists: /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2015-r9i1p1f1/Amon/tas/gn/
#
# >>748/777:<< local file: /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2015-r9i2p1f1/Amon/tas/gn/
# curl http://esgf-data1.llnl.gov/thredds/fileServer/css03_data/CMIP6/DCPP/NCC/NorCPM1/dcppA-hindcast/s2015-r9i2p1f1/Amon/tas/gn/v20190914/tas_Amon_NorCPM1_dcppA-hindcast_s2015-r9i2p1f1_gn_201510-202512.nc -o nctemp/tas_Amon_NorCPM1_dcppA-hindcast_s2015-r9i2p1f1_gn_201510-202512.nc
#
#
# /usr/bin/gsutil -m cp -r /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2015-r9i2p1f1/Amon/tas/gn gs://cmip6/DCPP/NCC/NorCPM1/dcppA-hindcast/s2015-r9i2p1f1/Amon/tas/gn
# successfully saved as /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2015-r9i2p1f1/Amon/tas/gn/
#
# >>749/777:<< local file: /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2016-r10i1p1f1/Amon/tas/gn/
# curl http://esgf-data1.llnl.gov/thredds/fileServer/css03_data/CMIP6/DCPP/NCC/NorCPM1/dcppA-hindcast/s2016-r10i1p1f1/Amon/tas/gn/v20190914/tas_Amon_NorCPM1_dcppA-hindcast_s2016-r10i1p1f1_gn_201610-202612.nc -o nctemp/tas_Amon_NorCPM1_dcppA-hindcast_s2016-r10i1p1f1_gn_201610-202612.nc
#
#
# /usr/bin/gsutil -m cp -r /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2016-r10i1p1f1/Amon/tas/gn gs://cmip6/DCPP/NCC/NorCPM1/dcppA-hindcast/s2016-r10i1p1f1/Amon/tas/gn
# successfully saved as /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2016-r10i1p1f1/Amon/tas/gn/
#
# >>750/777:<< local file: /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2016-r10i2p1f1/Amon/tas/gn/
# already exists: /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2016-r10i2p1f1/Amon/tas/gn/
#
# >>751/777:<< local file: /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2016-r2i1p1f1/Amon/tas/gn/
# already exists: /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2016-r2i1p1f1/Amon/tas/gn/
#
# >>752/777:<< local file: /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2016-r4i2p1f1/Amon/tas/gn/
# already exists: /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2016-r4i2p1f1/Amon/tas/gn/
#
# >>753/777:<< local file: /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2016-r5i2p1f1/Amon/tas/gn/
# already exists: /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2016-r5i2p1f1/Amon/tas/gn/
#
# >>754/777:<< local file: /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2016-r7i1p1f1/Amon/tas/gn/
# already exists: /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2016-r7i1p1f1/Amon/tas/gn/
#
# >>755/777:<< local file: /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2016-r7i2p1f1/Amon/tas/gn/
# already exists: /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2016-r7i2p1f1/Amon/tas/gn/
#
# >>756/777:<< local file: /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2016-r8i1p1f1/Amon/tas/gn/
# curl http://esgf-data1.llnl.gov/thredds/fileServer/css03_data/CMIP6/DCPP/NCC/NorCPM1/dcppA-hindcast/s2016-r8i1p1f1/Amon/tas/gn/v20190914/tas_Amon_NorCPM1_dcppA-hindcast_s2016-r8i1p1f1_gn_201610-202612.nc -o nctemp/tas_Amon_NorCPM1_dcppA-hindcast_s2016-r8i1p1f1_gn_201610-202612.nc
#
#
# /usr/bin/gsutil -m cp -r /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2016-r8i1p1f1/Amon/tas/gn gs://cmip6/DCPP/NCC/NorCPM1/dcppA-hindcast/s2016-r8i1p1f1/Amon/tas/gn
# successfully saved as /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2016-r8i1p1f1/Amon/tas/gn/
#
# >>757/777:<< local file: /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2016-r9i2p1f1/Amon/tas/gn/
# already exists: /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2016-r9i2p1f1/Amon/tas/gn/
#
# >>758/777:<< local file: /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2017-r10i2p1f1/Amon/tas/gn/
# already exists: /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2017-r10i2p1f1/Amon/tas/gn/
#
# >>759/777:<< local file: /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2017-r1i1p1f1/Amon/tas/gn/
# curl http://esgf-data1.llnl.gov/thredds/fileServer/css03_data/CMIP6/DCPP/NCC/NorCPM1/dcppA-hindcast/s2017-r1i1p1f1/Amon/tas/gn/v20190914/tas_Amon_NorCPM1_dcppA-hindcast_s2017-r1i1p1f1_gn_201710-202712.nc -o nctemp/tas_Amon_NorCPM1_dcppA-hindcast_s2017-r1i1p1f1_gn_201710-202712.nc
#
#
# /usr/bin/gsutil -m cp -r /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2017-r1i1p1f1/Amon/tas/gn gs://cmip6/DCPP/NCC/NorCPM1/dcppA-hindcast/s2017-r1i1p1f1/Amon/tas/gn
# successfully saved as /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2017-r1i1p1f1/Amon/tas/gn/
#
# >>760/777:<< local file: /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2017-r3i2p1f1/Amon/tas/gn/
# already exists: /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2017-r3i2p1f1/Amon/tas/gn/
#
# >>761/777:<< local file: /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2017-r5i1p1f1/Amon/tas/gn/
# already exists: /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2017-r5i1p1f1/Amon/tas/gn/
#
# >>762/777:<< local file: /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2017-r5i2p1f1/Amon/tas/gn/
# curl http://esgf-data1.llnl.gov/thredds/fileServer/css03_data/CMIP6/DCPP/NCC/NorCPM1/dcppA-hindcast/s2017-r5i2p1f1/Amon/tas/gn/v20190914/tas_Amon_NorCPM1_dcppA-hindcast_s2017-r5i2p1f1_gn_201710-202712.nc -o nctemp/tas_Amon_NorCPM1_dcppA-hindcast_s2017-r5i2p1f1_gn_201710-202712.nc
#
#
# /usr/bin/gsutil -m cp -r /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2017-r5i2p1f1/Amon/tas/gn gs://cmip6/DCPP/NCC/NorCPM1/dcppA-hindcast/s2017-r5i2p1f1/Amon/tas/gn
# successfully saved as /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2017-r5i2p1f1/Amon/tas/gn/
#
# >>763/777:<< local file: /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2017-r7i1p1f1/Amon/tas/gn/
# curl http://esgf-data1.llnl.gov/thredds/fileServer/css03_data/CMIP6/DCPP/NCC/NorCPM1/dcppA-hindcast/s2017-r7i1p1f1/Amon/tas/gn/v20190914/tas_Amon_NorCPM1_dcppA-hindcast_s2017-r7i1p1f1_gn_201710-202712.nc -o nctemp/tas_Amon_NorCPM1_dcppA-hindcast_s2017-r7i1p1f1_gn_201710-202712.nc
#
#
# /usr/bin/gsutil -m cp -r /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2017-r7i1p1f1/Amon/tas/gn gs://cmip6/DCPP/NCC/NorCPM1/dcppA-hindcast/s2017-r7i1p1f1/Amon/tas/gn
# successfully saved as /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2017-r7i1p1f1/Amon/tas/gn/
#
# >>764/777:<< local file: /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2017-r7i2p1f1/Amon/tas/gn/
# curl http://esgf-data1.llnl.gov/thredds/fileServer/css03_data/CMIP6/DCPP/NCC/NorCPM1/dcppA-hindcast/s2017-r7i2p1f1/Amon/tas/gn/v20190914/tas_Amon_NorCPM1_dcppA-hindcast_s2017-r7i2p1f1_gn_201710-202712.nc -o nctemp/tas_Amon_NorCPM1_dcppA-hindcast_s2017-r7i2p1f1_gn_201710-202712.nc
#
#
# /usr/bin/gsutil -m cp -r /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2017-r7i2p1f1/Amon/tas/gn gs://cmip6/DCPP/NCC/NorCPM1/dcppA-hindcast/s2017-r7i2p1f1/Amon/tas/gn
# successfully saved as /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2017-r7i2p1f1/Amon/tas/gn/
#
# >>765/777:<< local file: /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2017-r8i2p1f1/Amon/tas/gn/
# curl http://esgf-data1.llnl.gov/thredds/fileServer/css03_data/CMIP6/DCPP/NCC/NorCPM1/dcppA-hindcast/s2017-r8i2p1f1/Amon/tas/gn/v20190914/tas_Amon_NorCPM1_dcppA-hindcast_s2017-r8i2p1f1_gn_201710-202712.nc -o nctemp/tas_Amon_NorCPM1_dcppA-hindcast_s2017-r8i2p1f1_gn_201710-202712.nc
#
#
# /usr/bin/gsutil -m cp -r /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2017-r8i2p1f1/Amon/tas/gn gs://cmip6/DCPP/NCC/NorCPM1/dcppA-hindcast/s2017-r8i2p1f1/Amon/tas/gn
# successfully saved as /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2017-r8i2p1f1/Amon/tas/gn/
#
# >>766/777:<< local file: /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2018-r1i1p1f1/Amon/tas/gn/
# already exists: /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2018-r1i1p1f1/Amon/tas/gn/
#
# >>767/777:<< local file: /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2018-r1i2p1f1/Amon/tas/gn/
# curl http://esgf-data1.llnl.gov/thredds/fileServer/css03_data/CMIP6/DCPP/NCC/NorCPM1/dcppA-hindcast/s2018-r1i2p1f1/Amon/tas/gn/v20190914/tas_Amon_NorCPM1_dcppA-hindcast_s2018-r1i2p1f1_gn_201810-202812.nc -o nctemp/tas_Amon_NorCPM1_dcppA-hindcast_s2018-r1i2p1f1_gn_201810-202812.nc
#
#
# /usr/bin/gsutil -m cp -r /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2018-r1i2p1f1/Amon/tas/gn gs://cmip6/DCPP/NCC/NorCPM1/dcppA-hindcast/s2018-r1i2p1f1/Amon/tas/gn
# successfully saved as /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2018-r1i2p1f1/Amon/tas/gn/
#
# >>768/777:<< local file: /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2018-r2i1p1f1/Amon/tas/gn/
# already exists: /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2018-r2i1p1f1/Amon/tas/gn/
#
# >>769/777:<< local file: /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2018-r2i2p1f1/Amon/tas/gn/
# already exists: /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2018-r2i2p1f1/Amon/tas/gn/
#
# >>770/777:<< local file: /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2018-r3i2p1f1/Amon/tas/gn/
# already exists: /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2018-r3i2p1f1/Amon/tas/gn/
#
# >>771/777:<< local file: /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2018-r4i1p1f1/Amon/tas/gn/
# curl http://esgf-data1.llnl.gov/thredds/fileServer/css03_data/CMIP6/DCPP/NCC/NorCPM1/dcppA-hindcast/s2018-r4i1p1f1/Amon/tas/gn/v20190914/tas_Amon_NorCPM1_dcppA-hindcast_s2018-r4i1p1f1_gn_201810-202812.nc -o nctemp/tas_Amon_NorCPM1_dcppA-hindcast_s2018-r4i1p1f1_gn_201810-202812.nc
#
#
# /usr/bin/gsutil -m cp -r /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2018-r4i1p1f1/Amon/tas/gn gs://cmip6/DCPP/NCC/NorCPM1/dcppA-hindcast/s2018-r4i1p1f1/Amon/tas/gn
# successfully saved as /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2018-r4i1p1f1/Amon/tas/gn/
#
# >>772/777:<< local file: /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2018-r4i2p1f1/Amon/tas/gn/
# already exists: /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2018-r4i2p1f1/Amon/tas/gn/
#
# >>773/777:<< local file: /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2018-r5i2p1f1/Amon/tas/gn/
# already exists: /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2018-r5i2p1f1/Amon/tas/gn/
#
# >>774/777:<< local file: /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2018-r6i2p1f1/Amon/tas/gn/
# curl http://esgf-data1.llnl.gov/thredds/fileServer/css03_data/CMIP6/DCPP/NCC/NorCPM1/dcppA-hindcast/s2018-r6i2p1f1/Amon/tas/gn/v20190914/tas_Amon_NorCPM1_dcppA-hindcast_s2018-r6i2p1f1_gn_201810-202812.nc -o nctemp/tas_Amon_NorCPM1_dcppA-hindcast_s2018-r6i2p1f1_gn_201810-202812.nc
#
#
# /usr/bin/gsutil -m cp -r /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2018-r6i2p1f1/Amon/tas/gn gs://cmip6/DCPP/NCC/NorCPM1/dcppA-hindcast/s2018-r6i2p1f1/Amon/tas/gn
# successfully saved as /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2018-r6i2p1f1/Amon/tas/gn/
#
# >>775/777:<< local file: /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2018-r8i2p1f1/Amon/tas/gn/
# curl http://esgf-data1.llnl.gov/thredds/fileServer/css03_data/CMIP6/DCPP/NCC/NorCPM1/dcppA-hindcast/s2018-r8i2p1f1/Amon/tas/gn/v20190914/tas_Amon_NorCPM1_dcppA-hindcast_s2018-r8i2p1f1_gn_201810-202812.nc -o nctemp/tas_Amon_NorCPM1_dcppA-hindcast_s2018-r8i2p1f1_gn_201810-202812.nc
#
#
# /usr/bin/gsutil -m cp -r /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2018-r8i2p1f1/Amon/tas/gn gs://cmip6/DCPP/NCC/NorCPM1/dcppA-hindcast/s2018-r8i2p1f1/Amon/tas/gn
# successfully saved as /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2018-r8i2p1f1/Amon/tas/gn/
#
# >>776/777:<< local file: /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2018-r9i1p1f1/Amon/tas/gn/
# curl http://esgf-data1.llnl.gov/thredds/fileServer/css03_data/CMIP6/DCPP/NCC/NorCPM1/dcppA-hindcast/s2018-r9i1p1f1/Amon/tas/gn/v20190914/tas_Amon_NorCPM1_dcppA-hindcast_s2018-r9i1p1f1_gn_201810-202812.nc -o nctemp/tas_Amon_NorCPM1_dcppA-hindcast_s2018-r9i1p1f1_gn_201810-202812.nc
#
#
# /usr/bin/gsutil -m cp -r /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2018-r9i1p1f1/Amon/tas/gn gs://cmip6/DCPP/NCC/NorCPM1/dcppA-hindcast/s2018-r9i1p1f1/Amon/tas/gn
# successfully saved as /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2018-r9i1p1f1/Amon/tas/gn/
#
# >>777/777:<< local file: /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2018-r9i2p1f1/Amon/tas/gn/
# already exists: /h62/naomi/zarr-minimal/DCPP/NCC/NorCPM1/dcppA-hindcast/s2018-r9i2p1f1/Amon/tas/gn/

# %% [markdown]
# ### Make a table of acquired data to send in email to requestor

# %%
if len(zdict) == 0 :
    print('nothing else to do')
    exit
else:
    dz = dict_to_dfcat(zdict)

# %%
assert False
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-16-a871fdc9ebee> in <module>
# ----> 1 assert False
#
# AssertionError:

# %%
try:
    df_master_new = pd.concat([df_master, dz])
except:
    df_master_new = df_master
# Out:
# /usr/local/python/anaconda3/envs/pangeo-Oct2019/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.

# %%
#df_master_new = df_master

# %%
from response import response, dict_to_dfcat, get_details
from IPython.display import display

ldict = []
names = ""
print('Re: CMIP6 GCS Data Request (Responses)')
for row in df_request_new.values:
    rdict = dict(zip(df_request_new.keys(),row))
    #print(rdict)
    name = rdict['requester']
    timestamp = rdict['Timestamp']
    names += name
    del rdict['response status']
    ldict += [rdict]
    dfr = df_request_new[df_request_new.Timestamp == timestamp]
    
    print('Dear',name+':')
    print('\n  Here are the results from your recent CMIP6 data request(s).  The master catalog will be updated with the nightly build.')
    #if len(dtrouble)>=1:
    #    print('\n '+dtrouble)
    print('\n  Please note: ')
    print('      - Data for some models (e.g., CAS/FGOALS-f3-L and NUIST/NESM3) must be obtained directly from servers which are too slow or unresponsive. ')
    print('      - We exclude data with known errors (as reported at ES-DOC) from the official data catalog, https://errata.es-doc.org/ . ')
    print('      - Some data we have not been able to clean up enough to get it concatenated and save to zarr. Other datasets are only available for disjointed time periods.')
    print('\n  See the sample Jupyter Notebook at https://gist.github.com/naomi-henderson/ed1801d8ee8b992dda252f8b126876a5 for a quick introduction to accessing the data.')
    print('\nFrom the folks at:\n  The Climate Data Science Lab\n  Division of Ocean and Climate Physics\n  LDEO/Columbia University')
    print('\n--------------------------')

    print('\nrequest:')
    display(rdict)

    print('\nresponse:')
    try:
        print('new stores added:\n',len(dz),'\n')
    except:
        print(f'no new data available at ESGF API search node {ESGF_site}')

    #print('\n',dfr,len(df_master_new))
    table = response(dfr,df_master_new)

    print("\navailable data:\n  this includes your new stores but does not include datasets marked 'onhold', 'wontfix' or 'new' in the ES-DOC ERRATA")
    display(table)
    print('\n\n')
# Out:
# Re: CMIP6 GCS Data Request (Responses)
# Dear Naomi:
#
#   Here are the results from your recent CMIP6 data request(s).  The master catalog will be updated with the nightly build.
#
#   Please note:
#       - Data for some models (e.g., CAS/FGOALS-f3-L and NUIST/NESM3) must be obtained directly from servers which are too slow or unresponsive.
#       - We exclude data with known errors (as reported at ES-DOC) from the official data catalog, https://errata.es-doc.org/.
#       - Some data we have not been able to clean up enough to get it concatenated and save to zarr. Other datasets are only available for disjointed time periods.
#
#   See the sample Jupyter Notebook at https://gist.github.com/naomi-henderson/ed1801d8ee8b992dda252f8b126876a5 for a quick introduction to accessing the data.
#
# From the folks at:
#   The Climate Data Science Lab
#   Division of Ocean and Climate Physics
#   LDEO/Columbia University
#
# --------------------------
#
# request:
# {'Timestamp': '2/8/2020 0:11:43',
#  'E-mail': 'nhn2@columbia.edu',
#  'members': ['All'],
#  'experiments': ['dcppA-hindcast'],
#  'models': ['All'],
#  'variables': ['tas'],
#  'table': 'Amon',
#  'requester': 'Naomi',
#  'science': nan,
#  'comments': nan}
# response:
# new stores added:
#  508
#
# 165618 Amon
# 119788 ['dcppA-hindcast']
# 4849 ['tas']
#
# available data:
#   this includes your new stores but does not include datasets marked 'onhold', 'wontfix' or 'new' in the ES-DOC ERRATA
# variable_id                        tas
# experiment_id  source_id
# dcppA-hindcast BCC-CSM2-MR           8
#                CESM1-1-CAM5-CMIP5   40
#                CanESM5              20
#                MIROC6               10
#                MPI-ESM1-2-HR         5
#                NorCPM1              20

# %%
! mv csv/request_new.csv csv/requests.csv
