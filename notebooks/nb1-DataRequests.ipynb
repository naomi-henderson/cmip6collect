# %% [markdown]
# # To Handle New Data Requests Automatically
# - beginning of notebook is assumed to be interactive until the requests have been checked
# - all progress and exception logging is done only for main loop
# - copy and paste the e-mail response and send from gcs.cmip6.ldeo@gmail.com account

# %%
import numpy as np
import pandas as pd
import os
import gcsfs
import xarray as xr
from functools import partial

# %% [markdown]
# ### Local modules

# %%
from request import requests, set_request_id
from search import search, esgf_search_sites
from netcdf import get_ncfiles, concatenate
from identify import needed
from response import response, dict_to_dfcat, get_details

# %%
def getFolderSize(p):
    prepend = partial(os.path.join, p)
    return sum([(os.path.getsize(f) if os.path.isfile(f) else getFolderSize(f)) for f in map(prepend, os.listdir(p))])

# %% [markdown]
# ### Initialization

# %%
# Where to write NEW zarr stores:
zarr_local = '/h63/naomi/zarr-minimal'

fs = gcsfs.GCSFileSystem(token='anon', access='read_only')

# %% [markdown]
# ### Choose basic configuration parameters

# %%
dtype = esgf_search_sites()
print('possible ESGF API search nodes: ',list(dtype.keys()))
ESGF_site = dtype['llnl']
#ESGF_site = dtype['gfdl']
#ESGF_site = dtype['ipsl']

# List sites to skip for aquiring new netcdf files: broken or slow sites
skip_sites = ['esg.lasg.ac.cn','esgf-data2.diasjp.net'] # ,'esgf-data1.llnl.gov'] #['dist.nmlab.snu.ac.kr','esg.lasg.ac.cn'] # #]
# Out:
# possible ESGF API search nodes:  ['llnl', 'ipsl', 'nci', 'ceda', 'jpl', 'gfdl', 'dkrz']

# %% [markdown]
# ### Get prior Google Sheet requests

# %%
df_prior = pd.read_csv('csv/requests.csv')
df_prior
# Out:
#                Timestamp                                 E-mail                                    response status                   members                                        experiments                                             models                                          variables      table                 requester                                            science                                           comments
# 0      9/9/2019 14:13:56                  rpa@ldeo.columbia.edu                                               once                      ['']  ['1pctCO2', '1pctCO2-4xext', 'esm-ssp585', 'hi...                                            ['All']                                               ['']      Oclim                      Test   Trends in ocean heat budget under global warming                                                NaN
# 1     9/10/2019 16:51:18                naomi@ldeo.columbia.edu                                               once                      ['']                           ['ssp585', 'historical']  ['BCC-CSM2-MR', 'BNU-ESM-1-1', 'CAMS-CSM1-0', ...                          ['ps', 'ua', 'va', 'hus']       Amon                      Test  Compute atmospheric moisture budgets in future...                                                NaN
# 2     9/11/2019 15:21:35              ryan.abernathey@gmail.com                                               once                      ['']          ['esm-ssp585', 'historical', 'piControl']                                            ['All']  ['bigthetao', 'hfx', 'hfy', 'umo', 'uo', 'vmo'...       Omon                      Test                                  Ocean heat budget                                            Thanks!
# 3     9/11/2019 18:25:47                      nhn2@columbia.edu                                               once                      ['']                                     ['historical']                                            ['All']                    ['ps', 'hus', 'ua', 'va', 'ta']     6hrLev                      Test  Use the atmospheric moisture budget eddy terms...                                                NaN
# 4     9/12/2019 17:38:54                        mclong@ucar.edu                                               done                      ['']                     ['ssp126', 'ssp245', 'ssp585']                                            ['All']                                    ['o2', 'o2sat']        Oyr                 Matt Long                    Ocean oxygen in a warming world                                                NaN
# 5     9/12/2019 17:44:16                        mclong@ucar.edu                                               done                      ['']                               ['ssp245', 'ssp585']                                            ['All']                                         ['thetao']       Omon              Matthew Long                    Ocean oxygen in a warming world  Filter to include only models that have 'o2' a...
# 6     9/13/2019 12:18:31                         islas@ucar.edu                                               done                      ['']                 ['historical', 'ssp370', 'ssp585']                                            ['All']                           ['ua', 'va', 'ts', 'pr']       Amon              Isla Simpson  Test whether emergent constraints on the large...                                                NaN
# 7     9/16/2019 13:36:55                         afahad@gmu.edu                                               done                      ['']                     ['abrupt-4xCO2', 'historical']                                            ['All']  ['psl', 'ts', 'ua', 'va', 'pr', 'hfls', 'rlds'...       Amon         Abdullah al Fahad  large scale circulation change in CMIP5 and CM...  is it possible to get observed data of these v...
# 8     9/16/2019 14:29:37               sridge@ldeo.columbia.edu                                               done                      ['']                                     ['historical']                                            ['All']  ['thetao', 'so', 'dissic', 'no3', 'cfc11', 'sf...       Omon                Sean Ridge                                  CMIP6 Ocean Atlas                                                NaN
# 9     9/16/2019 16:28:13                       jhamman@ucar.edu                                               done                      ['']                 ['historical', 'ssp245', 'ssp585']                                            ['All']  ['pr', 'prc', 'rlds', 'rsds', 'sfcWind', 'hur'...        day                Joe Hamman      changes in hydrologic cycle and met extremes                                                 NaN
# 10    9/16/2019 16:30:01                      *jhamman@ucar.edu                                               once                      ['']                 ['historical', 'ssp245', 'ssp585']                                            ['All']                   ['hus', 'psl', 'ua', 'va', 'zg']    6hrPlev                      Test                          whatever I said before :)  talked to  jhamman@ucar.edu and decided to can...
# 11    9/16/2019 18:48:04                  bolliger@berkeley.edu                                               done                      ['']                             ['highresSST-present']                                            ['All']                               ['psl', 'pr', 'prc']      CF3hr              Ian Bolliger  The motivation is to characterize changes in t...                                                NaN
# 12    9/16/2019 20:41:45                  henrifdrake@gmail.com                                               done                      ['']             ['1pctCO2', 'historical', 'piControl']                                            ['All']      ['ta', 'ua', 'va', 'tas', 'pr', 'psl', 'hus']       Amon               Henri Drake  Calculating general model performance metrics ...                                                NaN
# 13    9/16/2019 20:43:24                  henrifdrake@gmail.com                                               done                      ['']             ['1pctCO2', 'historical', 'piControl']                                            ['All']                                         ['siconc']      SImon               Henri Drake  Evaluating sea ice simulations in CMIP6 agains...                                                NaN
# 14    9/17/2019 15:17:17               riley.brady@colorado.edu                                               once                      ['']                  ['dcppA-hindcast', 'dcppA-assim']                                         ['MIROC6']                                            ['tos']       Omon               Riley Brady  Providing analysis support for initialized dec...  It would be good to also get the available dcp...
# 15    9/17/2019 19:10:50               riley.brady@colorado.edu                                               once                      ['']  ['dcppA-assim', 'dcppA-hindcast', 'dcppC-hindc...                                        ['CanESM5']                                            ['tas']       Amon               Riley Brady  Providing analysis support for initialized dec...                                                NaN
# 16    9/17/2019 19:16:38               riley.brady@colorado.edu                                               once                      ['']                  ['dcppA-assim', 'dcppA-hindcast']                                        ['CanESM5']                                            ['tas']        day               Riley Brady  Providing analysis support for initialized dec...  only for a few initialization years (check mem...
# 17    9/17/2019 21:26:10                  bolliger@berkeley.edu                                               once                      ['']                             ['highresSST-present']                                            ['All']                 ['pr', 'prc', 'tas', 'uas', 'vas']        3hr              Ian Bolliger  The motivation is to characterize changes in t...                                                NaN
# 18     9/22/2019 6:17:48                      nhn2@columbia.edu                                               done                      ['']                                     ['historical']                                     ['CNRM-CM6-1']  ['clt', 'hfls', 'hfss', 'hur', 'hurs', 'hursma...        day           Naomi Henderson                                                NaN                                                NaN
# 19    9/23/2019 19:21:22                         yifanc6@uw.edu                                               done                      ['']    ['historical', 'piControl', 'ssp245', 'ssp585']                                            ['All']                         ['pr', 'tasmax', 'tasmin']        day               Yifan Cheng  I am interested in investigating the extreme e...                                                NaN
# 20    9/25/2019 10:45:50             spencerj@ldeo.columbia.edu                                                NaN                      ['']                                     ['historical']                                            ['All']         ['thetao', 'so', 'vmo', 'msftmrho', 'hfy']       Omon             Spencer Jones  Plotting ocean variables (especially heat and ...                                           Thanks!
# 21    9/25/2019 10:49:59             spencerj@ldeo.columbia.edu                                                NaN                      ['']                                     ['historical']                                            ['All']                           ['diftrblo', 'diftrelo']        Oyr             Spencer Jones             Ocean variables in density coordinates                                                NaN
# 22     9/26/2019 5:29:20                  bolliger@berkeley.edu              modified re: email exchange 9/26/2019                      ['']  ['highresSST-present', 'hist-1950', 'control-1...                                            ['All']                                             ['pr']        day              Ian Bolliger  The motivation is to characterize changes in t...
# 23     9/26/2019 5:31:08                  bolliger@berkeley.edu              modified re: email exchange 9/26/2019                      ['']  ['highresSST-present', 'hist-1950', 'control-1...                                            ['All']                       ['psl', 'uas', 'vas', 'tas']  6hrPlevPt              Ian Bolliger  The motivation is to characterize changes in t...
# 24    9/26/2019 12:17:32                  bolliger@berkeley.edu                 added re: email exchange 9/26/2019                      ['']  ['highresSST-present', 'hist-1950', 'control-1...                                            ['All']                       ['psl', 'uas', 'vas', 'tas']    6hrPlev              Ian Bolliger  The motivation is to characterize changes in t...                                                NaN
# 25     9/27/2019 4:06:54                      yeddebba@ucsd.edu                                                NaN                      ['']  ['historical', 'omip1', 'piControl', 'ssp126',...                                            ['All']  ['thetao', 'so', 'agessc', 'uo', 'vo', 'wo', '...       Omon           Yassir Eddebbar  Understanding 20th century evolution and futur...                                                NaN
# 26     9/27/2019 4:15:52                      yeddebba@ucsd.edu                                                NaN                      ['']  ['historical', 'omip1', 'piControl', 'ssp126',...                                            ['All']  ['basin', 'thkcello', 'volcello', 'sftof', 'ar...        Ofx           Yassir Eddebbar                          oxygen and carbon, part 2  Thank you! This will have such a positive impa...
# 27     9/27/2019 4:28:34                      yeddebba@ucsd.edu                                                NaN                      ['']  ['historical', 'omip1', 'piControl', 'ssp126',...                                            ['All']                        ['psl', 'ts', 'uas', 'vas']       Amon           Yassir Eddebbar                         carbon and oxygen, part 3.                                                NaN
# 28     9/27/2019 8:55:38             spencerj@ldeo.columbia.edu                                                NaN                      ['']                                     ['historical']                                            ['All']                                         ['msftmz']       Omon             Spencer Jones             Ocean variables in density coordinates                 Realized this would be useful too!
# 29    9/27/2019 12:12:53                jim.christian@canada.ca                                                NaN                      ['']    ['historical', 'piControl', 'ssp245', 'ssp585']                                            ['All']  ['dissic', 'talk', 'no3', 'po4', 'si', 'o2', '...        Oyr             Jim Christian              ocean CO2 uptake and CaCO3 saturation                                                NaN
# 30    9/27/2019 15:30:03                        berner@ucar.edu                                                NaN                      ['']                                      ['piControl']                              ['CESM2', 'GFDL-CM4']                                            ['tas']       Amon             Judith Berner                                               ENSO                                                NaN
# 31    9/27/2019 16:03:48              clepore@ldeo.columbia.edu                                               once                      ['']                                     ['historical']                                            ['All']                    ['ua', 'va', 'hus', 'ta', 'ps']     6hrLev             Chiara Lepore  Calculating CAPE and SRH in the CMIP6 models, ...                                                NaN
# 32    9/27/2019 16:04:54              clepore@ldeo.columbia.edu                                               once                      ['']                                     ['historical']                                            ['All']                              ['uas', 'vas', 'tas']        3hr             Chiara Lepore                                                NaN                                                NaN
# 33    9/27/2019 16:51:08                           jml1@mit.edu                                                NaN                      ['']  ['1pctCO2', '1pctCO2-bgc', 'abrupt-4xCO2', 'es...                                            ['All']  ['agessc', 'bacc', 'bfe', 'bigthetao', 'bsi', ...       Omon       Jonathan Lauderdale  Ocean biogeochemistry data: carbon uptake, sto...                                                NaN
# 34    9/27/2019 17:00:07                           jml1@mit.edu                                                NaN                      ['']  ['1pctCO2', '1pctCO2-bgc', 'abrupt-4xCO2', 'es...                                            ['All']  ['arag', 'bacc', 'bddtalk', 'bddtdic', 'bddtdi...        Oyr       Jonathan Lauderdale  Ocean carbon uptake, storage, and cycling: pas...                                                NaN
# 35    9/27/2019 19:15:20                        chiangf@uci.edu                                                NaN                      ['']  ['historical', 'piControl', 'ssp126', 'ssp245'...                                            ['All']                  ['tas', 'tasmax', 'tasmin', 'pr']       Amon            Felicia Chiang         Time of emergence of climate change signal                                                NaN
# 36    9/27/2019 19:27:06             ariannav@ldeo.columbia.edu                                                NaN                      ['']  ['amip', 'esm-hist', 'esm-piControl', 'histSST...                                          ['CESM2']                   ['zg', 'psl', 'ps', 'pr', 'prc']       Amon    Arianna Varuolo-Clarke  How does hydroclimate variability over South A...                                                NaN
# 37     9/30/2019 3:48:08             ariannav@ldeo.columbia.edu                                                NaN                      ['']  ['amip', 'esm-hist', 'esm-piControl', 'histSST...                                          ['CESM2']                                  ['mrsos', 'mrso']       Lmon    Arianna Varuolo-Clarke  How does hydroclimate variability over South A...                                                NaN
# 38     9/30/2019 5:27:47             ariannav@ldeo.columbia.edu                                                NaN                      ['']  ['amip', 'esm-hist', 'esm-piControl', 'histSST...                                          ['CESM2']                                            ['tos']       Omon    Arianna Varuolo-Clarke  How does hydroclimate variability over South A...                                                NaN
# 39    10/2/2019 17:31:41                        diamond2@uw.edu                                                NaN                      ['']                                 ['deforest-globe']                                            ['All']  ['ua', 'va', 'rsds', 'rsus', 'rlus', 'rlds', '...       Amon           Michael Diamond  Land use change (global-deforestation): Effect...                                                NaN
# 40    10/2/2019 17:36:36                        diamond2@uw.edu                                                NaN                      ['']                                 ['deforest-globe']                                            ['All']                               ['treeFrac', 'cVeg']       Lmon           Michael Diamond    Land use (global-deforest): Circulation changes                                                NaN
# 41    10/2/2019 17:56:19                        czarakas@uw.edu                                                NaN                      ['']  ['historical', 'ssp126', 'ssp245', 'ssp370', '...                                            ['All']          ['tas', 'pr', 'prsn', 'tasmax', 'tasmin']       Amon            Claire Zarakas               Visualizations for Public Engagement                                                NaN
# 42    10/3/2019 13:33:40                          lroach@uw.edu  modified after e-mail exchange (I still don't ...                      ['']                        ['historical', 'piControl']                                            ['All']  ['thetao', 'so', 'rhopoto', 'uo', 'vo', 'umo',...       Omon              Lettie Roach  Southern Ocean bottom water and sea ice in CMI...                                                NaN
# 43    10/3/2019 13:34:35                          lroach@uw.edu                                                NaN                      ['']                        ['historical', 'piControl']                                            ['All']                              ['siconc', 'sithick']      SImon              Lettie Roach  Southern Ocean bottom water and sea ice in CMI...                                                NaN
# 44    10/3/2019 16:17:03                  bolliger@berkeley.edu                                                NaN                      ['']  ['highresSST-present', 'hist-1950', 'control-1...                                            ['All']                                             ['ta']  6hrPlevPt              Ian Bolliger  The motivation is to characterize changes in t...                                                NaN
# 45    10/3/2019 21:39:07                      yeddebba@ucsd.edu                                                NaN                      ['']    ['historical', 'piControl', 'ssp126', 'ssp585']                                            ['All']  ['[agessc', 'wo', 'msftmz', 'obvfsq', 'fgco2',...        Oyr           Yassir Eddebbar                ocean-bgc shorter priority list Oyr                                Nope! Thanks Naomi!
# 46     10/4/2019 0:40:58                      stephens@ucar.edu              added hist-bgc to list of experiments                      ['']                         ['historical', 'hist-bgc']                                            ['All']  ['fgo2', 'fgco2', 'fgco2abio', 'fgco2nat', 'to...       Omon            Britt Stephens  Testing model representation of seasonal air-s...  These should all be 2d monthly fields, so hope...
# 47     10/4/2019 9:43:34                jim.christian@canada.ca                                                NaN                      ['']    ['historical', 'piControl', 'ssp245', 'ssp585']                                            ['All']                            ['epc100', 'epcalc100']       Omon             Jim Christian              ocean CO2 uptake and CaCO3 saturation                                                NaN
# 48    10/4/2019 18:06:57                         mclaret@uw.edu                                                NaN                      ['']    ['1pctCO2', 'historical', 'omip1', 'piControl']  ['CNRM-CM6-1-HR', 'CNRM-ESM2-1-HR', 'EC-Earth3...               ['o2', 'o2sat', 'fgco2', 'fgco2nat']        Oyr            Mariona Claret  Characterization of the Gulf Stream in transie...  Could not find air-sea carbon fluxes, I likely...
# 49     10/9/2019 9:57:43             ariannav@ldeo.columbia.edu                                                NaN                      ['']                                      ['piControl']                                            ['All']                   ['pr', 'prc', 'ps', 'psl', 'zg']       Amon    Arianna Varuolo-Clarke  How does hydroclimate variability over South A...                                                NaN
# 50     10/9/2019 9:58:46             ariannav@ldeo.columbia.edu                                                NaN                      ['']                                      ['piControl']                                            ['All']                                  ['mrso', 'mrsos']       Lmon    Arianna Varuolo-Clarke  How does hydroclimate variability over South A...                                                NaN
# 51     10/9/2019 9:59:52             ariannav@ldeo.columbia.edu                                                NaN                      ['']                     ['esm-piControl', 'piControl']                                            ['All']                                            ['tos']       Omon    Arianna Varuolo-Clarke  How does hydroclimate variability over South A...                                       Thank you!!
# 52   10/10/2019 14:49:58                         mmsmith@uw.edu                                                NaN                      ['']  ['1pctCO2', 'abrupt-4xCO2', 'historical', 'piC...                                            ['All']  ['siarean', 'siareas', 'siconc', 'siconca', 's...      SImon             Madison Smith  Sensitivity of sea ice to changes in air tempe...                                                NaN
# 53   10/10/2019 14:52:53                         mmsmith@uw.edu                                            testing                      ['']  ['1pctCO2', 'abrupt-4xCO2', 'historical', 'piC...                                            ['All']                                         ['rld-no']      CFmon             Madison Smith  Sensitivity of sea ice to changes in air tempe...                                                NaN
# 54   10/10/2019 14:54:23                         mmsmith@uw.edu                                                NaN                      ['']  ['1pctCO2', 'abrupt-4xCO2', 'historical', 'piC...                                            ['All']                                            ['tas']       Amon             Madison Smith  Sensitivity of sea ice to changes in air tempe...                                                NaN
# 55   10/10/2019 14:56:27                         mmsmith@uw.edu                                                NaN                      ['']  ['1pctCO2', 'abrupt-4xCO2', 'historical', 'piC...                                            ['All']                                            ['tos']       Omon             Madison Smith  Sensitivity of sea ice to changes in air tempe...                                                NaN
# 56   10/10/2019 14:58:02                         mmsmith@uw.edu                                                NaN                      ['']  ['1pctCO2', 'abrupt-4xCO2', 'historical', 'piC...                                            ['All']                                      ['areacello']        Ofx             Madison Smith  Sensitivity of sea ice to changes in air tempe...                                                NaN
# 57    10/11/2019 9:23:23                       apgrass@ucar.edu                                                NaN                      ['']  ['1pctCO2', 'abrupt-4xCO2', 'historical', 'piC...                                            ['All']                                             ['pr']        day         Angie Pendergrass  My goal is to evaluate results on precipitatio...                                                NaN
# 58    10/11/2019 9:26:59                       apgrass@ucar.edu                                                NaN                      ['']  ['1pctCO2', 'abrupt-4xCO2', 'historical', 'piC...                                            ['All']                        ['pr', 'tas', 'huss', 'ts']       Amon         Angie Pendergrass  I would like to examine precipitation and how ...                                                NaN
# 59   10/11/2019 13:00:29                        kdagon@ucar.edu                                                NaN                      ['']    ['esm-ssp585', 'esm-ssp585-ssp126Lu', 'ssp585']                                            ['All']  ['cLeaf', 'cVeg', 'gpp', 'lai', 'nbp', 'npp', ...       Lmon               Katie Dagon  How do CMIP6 models simulate future changes in...                                                NaN
# 60   10/11/2019 19:03:28                         rcwills@uw.edu                                                NaN                      ['']                           ['hist-GHG', 'hist-aer']                                            ['All']  ['ts', 'tas', 'psl', 'pr', 'ta', 'ua', 'va', '...       Amon       Robert Jnglin Wills  Isolating aerosol-forced and greenhouse-gas fo...                                                NaN
# 61   10/11/2019 19:04:45                         rcwills@uw.edu                                                NaN                      ['']                           ['hist-GHG', 'hist-aer']                                            ['All']                                            ['tos']       Omon       Robert Jnglin Wills         SST changes due to aerosol and GHG forcing                                                NaN
# 62   10/14/2019 10:51:40             spencerj@ldeo.columbia.edu                                                NaN                      ['']                                     ['historical']                                            ['All']                           ['diftrelo', 'diftrblo']      Oclim             Spencer Jones                   Variables in density coordinates  No worries if you don't get to this - I know i...
# 63   10/15/2019 23:45:29                        dbalwada@uw.edu                                                NaN                      ['']                        ['historical', 'piControl']                                            ['All']                                            ['vsf']       Omon             Dhruv Balwada  Estimating water mass transformation rates in ...  Most of the heat fluxes are there on the cloud...
# 64   10/17/2019 18:09:18                  jiacan.yuan@gmail.com                                                NaN                      ['']  ['1pctCO2', 'abrupt-4xCO2', 'ssp126', 'ssp245'...                                            ['All']                                            ['zos']       Omon               Jiacan Yuan  I am going to request sea level rise data proj...           I just need the monthly frequency data.
# 65    11/8/2019 11:44:12                    naominaik@gmail.com                                               once                     ['2']                                   ['abrupt-2xCO2']                                            ['All']                ['co3', 'detoc', 'dfe', 'diftrblo']       Omon                      Test                                                NaN                                                NaN
# 66    11/9/2019 10:34:23                    naominaik@gmail.com                                               once  ['r1i1p1f1', 'r1i1p1f2']                                         ['ssp222']                              ['BCC-ESM1', 'CESM2']                                     ['huss', 'pr']        3hr                      Test                                                NaN                                                NaN
# 67   11/10/2019 11:05:14                naomi@ldeo.columbia.edu                                               once                   ['All']                                            ['All']                                            ['All']                     ['hfgeoubed', 'lithk', 'topg']     IfxGre           Naomi Henderson                                                NaN                                                NaN
# 68    11/16/2019 7:59:19                      nhn2@columbia.edu                                               once              ['r1i1p1f1']                                     ['historical']                                       ['GFDL-CM4']                              ['tas', 'uas', 'vas']        day           Naomi Henderson                                                NaN                                                NaN
# 69   11/25/2019 21:23:24                      nhn2@columbia.edu                                                NaN                   ['All']  ['1pctCO2', 'abrupt-4xCO2', 'hist-GHG', 'histo...                                            ['All']  ['tas', 'uas', 'vas', 'pr', 'psl', 'rlut', 'rs...       Amon           Naomi Henderson                                                NaN                                                NaN
# 70   11/25/2019 21:24:57                      nhn2@columbia.edu                                                NaN                   ['All']  ['1pctCO2', 'abrupt-4xCO2', 'hist-GHG', 'histo...                                            ['All']                                         ['siconc']      SImon           Naomi Henderson                                                NaN                                                NaN
# 71    12/10/2019 9:37:31                      schupfner@dkrz.de                                                NaN                   ['All']                                         ['ssp585']                                  ['MPI-ESM1-2-HR']                                ['tas', 'ps', 'ta']       Amon          Martin Schupfner  Contributor to CMIP6 ScenarioMIP, interested i...                                                NaN
# 72   12/10/2019 14:50:11              nandi.pritam007@gmail.com                                                NaN                   ['All']                 ['historical', 'ssp245', 'ssp585']                                            ['All']            ['tasmax', 'tasmin', 'prra', 'sfcWind']     Esubhr             Saswata Nandi                        Extreme flooding over India                                                NaN
# 73   12/10/2019 20:35:53                      1047071113@qq.com                                                NaN                   ['All']                              ['1pctCO2', 'ssp245']                                            ['All']                                             ['pr']       Amon               yang xianke                                           research                                                  1
# 74    12/11/2019 3:51:36          bbronselaer@email.arizona.edu                                                NaN                   ['All']                                        ['1pctCO2']                                            ['All']                                            ['tos']       Omon            Ben Bronselaer  Test hypothesis about effect of ocean circulat...                                                NaN
# 75    12/13/2019 9:24:56               serguei.nikonov@noaa.gov                                                NaN                   ['One']                                        ['1pctCO2']                                       ['GFDL-CM4']                                            ['ccb']       Amon            Sergey Nikonov     all; purpose: for assessment of this approach                                                 NaN
# 76    12/13/2019 9:48:41               serguei.nikonov@noaa.gov                                                NaN                   ['One']                                           ['amip']                                       ['GFDL-AM4']                                            ['hus']       Amon            Sergey Nikonov                                                NaN                                                NaN
# 77    12/14/2019 9:01:42                    bubslug67@gmail.com                                                NaN                   ['One']                                     ['historical']                                            ['All']                                     ['tas', 'tos']       Omon                  Bub Slug                          Climate analysis hobbyist                                               none
# 78    12/15/2019 8:50:37                 gaurav.bhugp@gmail.com                                                NaN                   ['One']  ['historical', 'piControl', 'ssp126', 'ssp245'...                                            ['All']                                       ['pr', 'ts']       Amon         Gaurav Srivastava  Indian summer monsoon variability under the an...                                                NaN
# 79   12/15/2019 21:16:14        liuyufu18@mails.tsinghua.edu.cn                                                NaN                   ['All']                                        ['1pctCO2']                                            ['All']                                         ['siconc']      SImon                  Liu Yufu  dataset interoperability infrustructure develo...                                                NaN
# 80    12/16/2019 2:34:29           wangxiong961615861@gmail.com                                                NaN                   ['All']                                           ['amip']                                            ['All']        ['albsn', 'simpconc', 'simpmass', 'sisali']      SImon                wang xiong               data analysis for meltpond in Arctic                                                NaN
# 81   12/16/2019 14:19:04          trondkr@faralloninstitute.org                                                NaN              ['r1i1p1f1']  ['1pctCO2', 'esm-hist', 'esm-piControl', 'esm-...                                            ['All']                                      ['sisnthick']      SImon         Trond Kristiansen  I would like to calculate future Arctic light ...  I greatly appreciate how much easier it is to ...
# 82   12/16/2019 22:48:15                       vgensini@niu.edu                                               once              ['r1i1p1f1']                                     ['historical']                                       ['GFDL-CM4']                    ['ta', 'ps', 'ua', 'va', 'hus']     6hrLev            Victor Gensini  GFDL-CM4 model level or pressure level data (s...                                                NaN
# 83   12/16/2019 23:04:10          trondkr@faralloninstitute.org                                                NaN              ['r1i1p1f1']  ['1pctCO2', 'abrupt-4xCO2', 'esm-hist', 'esm-p...                                            ['All']                           ['sisnconc', 'albisccp']      SImon         Trond Kristiansen  I would like to calculate future Arctic light ...  I greatly appreciate how much easier it is to ...
# 84    12/18/2019 5:26:43                fedor.baart@deltares.nl                                                NaN                   ['All']  ['esm-hist', 'esm-piControl', 'historical', 's...                                            ['All']                                            ['zos']       Omon              Fedor  Baart                            Sea-level rise research                                                NaN
# 85   12/18/2019 18:46:52                  jliu@spacescience.org                                                NaN                   ['All']                       ['G6solar', 'amip-future4K']                                       ['GFDL-AM4']                                          ['acabf']       Amon                Junjun Liu  Analyze state-of-the-art simulations of global...                                                NaN
# 86   12/19/2019 11:20:40                     pageweil@gmail.com                                                NaN                   ['All']  ['historical', 'piControl', 'ssp126', 'ssp245'...                                            ['All']           ['tas', 'tasmax', 'tasmin', 'pr', 'prw']        day                 Page Weil  I am a hydrologist who studies how various cli...  Is this data available through a portal that a...
# 87   12/20/2019 16:52:42                 chandrarupar@gmail.com                                                NaN                   ['All']                                     ['historical']                                            ['All']                                      ['pr', 'tas']        day   Chandra Rupa Rajulapati  Hydro-meteorological variables like temperatur...                                                NaN
# 88   12/20/2019 17:22:11                 jiwoolee1043@gmail.com                                                NaN                   ['All']                                     ['historical']                                     ['ACCESS-CM2']                                      ['ts', 'psl']       Amon                 Jiwoo Lee        Climate model evaluation metric development                                                NaN
# 89     1/3/2020 15:08:15              sepideh@descarteslabs.com                                                NaN                   ['All']  ['historical', 'ssp126', 'ssp245', 'ssp370', '...                                            ['All']                                 ['zos', 'zostoga']       Omon          Sepideh Khajehei                               Climate risk studies                                                NaN
# 90      1/8/2020 4:07:13             aaron.spring@mpimet.mpg.de                                               once                   ['All']  ['dcppA-hindcast', 'dcppB-forecast', 'esm-piCo...                                            ['All']                   ['fgco2', 'intpp', 'tos', 'sos']       Omon              Aaron Spring                    PhD carbon cycle predictability                                                NaN
# 91    1/15/2020 18:51:28                 jules.kajtar@gmail.com                                                NaN                   ['All']                           ['historical', 'ssp585']                                            ['All']                                            ['tas']       Amon              Jules Kajtar      Understanding the drivers of marine heatwaves                                                NaN
# 92    1/20/2020 15:43:33                fedor.baart@deltares.nl                                                NaN                   ['All']  ['esm-piControl', 'historical', 'piControl', '...                                            ['All']                                            ['zos']       Omon               Fedor Baart                         Sea-level rise projections                                                NaN
# 93     1/22/2020 9:45:20              joshua.studholme@yale.edu                                                NaN                   ['One']  ['historical', 'ssp126', 'ssp245', 'ssp370', '...                                            ['All']                                 ['clivi', 'clwvi']       Amon            Josh Studholme  I'm looking to get ice water path (clivi) and ...              Thank you very much for this project!
# 94    1/23/2020 20:45:40              joshua.studholme@yale.edu                                                NaN                   ['One']  ['historical', 'ssp126', 'ssp245', 'ssp370', '...                                            ['All']               ['rlut', 'rlutcs', 'rsut', 'rsutcs']       Amon            Josh Studholme                                                NaN                                         Thank you!
# 95    1/23/2020 20:47:07             joshua.studholme@gmail.com                                                NaN                   ['One']  ['historical', 'ssp126', 'ssp245', 'ssp370', '...                                            ['All']                                           ['cltc']     AERmon            Josh Studholme                                                NaN                               Thank you very much!
# 96    1/29/2020 15:57:32              trond.kristiansen@niva.no                                                NaN              ['r1i1p1f1']  ['1pctCO2', '1pctCO2-4xext', '1pctCO2-bgc', 'a...                                            ['All']  ['intdoc', 'limirrmisc', 'chldiaz', 'chldiat',...       Omon         Trond Kristiansen  I would like to calculate future Arctic light ...                                         Thank you!
# 97    1/29/2020 17:24:30                         orianac@uw.edu                                                NaN                   ['All']  ['historical', 'ssp126', 'ssp245', 'ssp370', '...                                            ['All']           ['mrro', 'hfls', 'snw', 'mrso', 'mrsos']        day         Oriana Chegwidden  How will hydrologic droughts, particularly tho...  Thanks so much for your help! Please let me kn...
# 98    1/30/2020 17:07:03          trondkr@faralloninstitute.org                                                NaN              ['r1i1p1f1']  ['1pctCO2', 'abrupt-4xCO2', 'esm-piControl', '...                                            ['All']  ['chlmiscos', 'chldiazos', 'chlos', 'dissocos'...       Omon         Trond Kristiansen  I have previously been granted more variables ...                                      Thanks again!
# 99    1/31/2020 18:28:16                jmontenegrog@uni.edu.pe                                                NaN                   ['One']           ['ssp126', 'ssp245', 'ssp370', 'ssp585']                                     ['ACCESS-CM2']                                             ['pr']        day  Julio Montenegro Gambini  Master Thesis related to climate change and hy...                                                NaN
# 100     2/2/2020 7:49:02                naomi@ldeo.columbia.edu                                               once              ['r1i1p1f1']                                   ['abrupt-4xCO2']                                   ['IPSL-CM6A-LR']  ['chl', 'no3', 'si', 'o2', 'pp', 'expc', 'phyc...        Oyr                     Naomi                                                NaN                                                NaN
# 101    2/3/2020 17:59:12          trondkr@faralloninstitute.org                                                NaN              ['r1i1p1f1']  ['1pctCO2', 'esm-hist', 'esm-ssp585', 'histori...                                            ['All']  ['sithick', 'siconc', 'sisnthick', 'sisnconc',...      SImon         Trond Kristiansen  I have previously requested data for an analsy...                                         Thank you!
# 102    2/4/2020 16:38:00                      adessler@tamu.edu                                                NaN                   ['All']                      ['abrupt-4xCO2', 'piControl']                                            ['All']                                        ['clisccp']      CFmon            Andrew Dessler  analyzing cloud feedback in control runs and i...                                                NaN
# 103    2/5/2020 12:37:14                  shunzlu@sas.upenn.edu                                                NaN                   ['One']                                     ['historical']  ['CanESM5', 'CESM2', 'CESM2-WACCM', 'CNRM-ESM2...  ['phyc', 'phydiat', 'zooc', 'dfe', 'si', 'rsnt...       Omon                 Shunzi Lu  linking the seasonal cycle of plankton ecology...                                                NaN
# 104     2/7/2020 6:05:06                 mpb20@st-andrews.ac.uk                                                NaN                   ['One']  ['historical', 'ssp126', 'ssp245', 'ssp370', '...                                            ['All']                                    ['tas', 'huss']        day             Michael Byrne  Hi there,I'm working on a new paper looking at...  That's it, thanks a lot for setting up this aw...
# 105    2/7/2020 17:27:22              joshua.studholme@yale.edu                                                NaN                   ['One']                                         ['ssp585']                                            ['All']  ['tas', 'pr', 'clwvi', 'clivi', 'rlut', 'rlutc...       Amon            Josh Studholme                                                NaN  I'm sorry for asking for this again, I've seen...
# 106     2/8/2020 0:11:43                      nhn2@columbia.edu                                                NaN                   ['All']                                 ['dcppA-hindcast']                                            ['All']                                            ['tas']       Amon                     Naomi                                                NaN                                                NaN
# 107    2/15/2020 0:44:27                  shunzlu@sas.upenn.edu                                                NaN                   ['One']                                     ['historical']                                        ['NorCPM1']                                            ['tos']       Omon                 Shunzi Lu  How are air-sea CO2 fluxes influenced by plank...                               Thank you very much!
# 108    2/19/2020 3:23:49               gisluoxiaolong@gmail.com                                                NaN                   ['All']                                     ['lfmip-pdLC']                                    ['UKESM1-0-LL']                              ['sfcWind', 'pr', '']       Eday              Xiaolong,Luo  I need the simulated wind speed data in the fu...                                                NaN
# 109   2/21/2020 13:28:20                landon.rieger@gmail.com                                                NaN                   ['All']                                     ['historical']                                        ['CanESM5']                                             ['ta']        day             Landon Rieger  Temperature anomalies in the stratosphere in t...  This is a fantastic tool. This and google cola...
# 110   2/23/2020 15:48:48  duncan.watson-parris@physics.ox.ac.uk                                                NaN                   ['One']  ['hist-aer', 'histSST', 'piClim-aer', 'piClim-...                                            ['All']  ['od550aer', 'rlutaf', 'rlutcsaf', 'rsutaf', '...     AERmon      Duncan Watson-Parris  Exploring historical and projected (anthropoge...  The associated radiative fluxes (r{s,l}{u,d}t)...
# 111    2/28/2020 6:34:28      william.roberts@northumbria.ac.uk                                                NaN                   ['One']                                      ['piControl']                                            ['All']                                            ['tas']       Amon           William Roberts                                     paleoclimate\n                                                NaN
# 112           2019-10-02               sridge@ldeo.columbia.edu                                                NaN                      ['']                                     ['historical']                                          ['CESM2']  ['thetao', 'so', 'dissic', 'no3', 'cfc11', 'sf...       Omon                Sean Ridge                                  CMIP6 Ocean Atlas               as many ensemble members as possible
# 113   9/27/2019 15:30:03                        berner@ucar.edu                                                NaN                      ['']                                      ['piControl']                              ['CESM2', 'GFDL-CM4']                                     ['ua', 'rlut']        day             Judith Berner                                               ENSO                                                NaN
# 114  10/10/2019 14:52:53                         mmsmith@uw.edu                                                NaN                      ['']  ['1pctCO2', 'abrupt-4xCO2', 'historical', 'piC...                                            ['All']                                   ['rlus', 'rlds']       Amon             Madison Smith  Sensitivity of sea ice to changes in air tempe...                                                NaN
# 115  12/16/2019 23:04:10          trondkr@faralloninstitute.org                                                NaN              ['r1i1p1f1']  ['1pctCO2', 'abrupt-4xCO2', 'esm-hist', 'esm-p...                                            ['All']                                       ['albisccp']      CFmon         Trond Kristiansen                                                NaN                                                NaN
# 116  12/16/2019 22:48:15                       vgensini@niu.edu                                               once              ['r1i1p1f1']                                     ['historical']                          ['GFDL-CM4', 'GFDL-ESM4']  ['tas', 'ta', 'ps', 'ua', 'va', 'psl', 'zg500'...     6hrLev            Victor Gensini                                   original request                                                NaN
# 117   9/27/2019 16:03:48              clepore@ldeo.columbia.edu                                               once  ['r1i1p1f1', 'r1i1p1f2']                                         ['ssp585']  ['BCC-CSM2-MR', 'CNRM-CM6-1', 'MRI-ESM2-0', 'I...                    ['ua', 'va', 'hus', 'ta', 'ps']     6hrLev             Chiara Lepore  Calculating CAPE and SRH in the CMIP6 models, ...                                                NaN
# 118   9/27/2019 16:04:54              clepore@ldeo.columbia.edu                                               once  ['r1i1p1f1', 'r1i1p1f2']                                         ['ssp585']  ['BCC-CSM2-MR', 'CNRM-CM6-1', 'MRI-ESM2-0', 'I...                      ['uas', 'vas', 'tas', 'huss']        3hr             Chiara Lepore                                                NaN                                                NaN
# 119           2019-12-17              clepore@ldeo.columbia.edu                                               once  ['r1i1p1f1', 'r1i1p1f2']                                     ['historical']  ['BCC-CSM2-MR', 'CNRM-CM6-1', 'MRI-ESM2-0', 'I...                      ['uas', 'vas', 'tas', 'huss']        3hr             Chiara Lepore                                                new                                                NaN
# 120           2019-12-17              clepore@ldeo.columbia.edu                                               once  ['r1i1p1f1', 'r1i1p1f2']                           ['historical', 'ssp585']                                       ['GFDL-CM4']                      ['uas', 'vas', 'tas', 'huss']        3hr             Chiara Lepore                                                new                                                NaN
# 121           2019-12-18              clepore@ldeo.columbia.edu                                               once  ['r1i1p1f1', 'r1i1p1f2']                                     ['historical']                                     ['MRI-ESM2-0']                                            ['hus']     6hrLev             Chiara Lepore                                                NaN                                                NaN
# 122           2019-12-19              clepore@ldeo.columbia.edu                                               once  ['r1i1p1f1', 'r1i1p1f2']                                         ['ssp585']                                     ['MRI-ESM2-0']                      ['uas', 'vas', 'tas', 'huss']        3hr             Chiara Lepore                                                new                                                NaN
# 123           2019-12-19              clepore@ldeo.columbia.edu                                               once  ['r1i1p1f1', 'r1i1p1f2']                                         ['ssp585']                                    ['CNRM-ESM2-1']                                     ['uas', 'vas']       E3hr             Chiara Lepore                                                new                                                NaN
# 124  12/16/2019 14:19:04          trondkr@faralloninstitute.org                                                NaN              ['r1i1p1f1']  ['1pctCO2', 'esm-hist', 'esm-piControl', 'esm-...                                            ['All']     ['sisnthick', 'sisnconc', 'siconc', 'sithick']      SImon         Trond Kristiansen                                                NaN  I greatly appreciate how much easier it is to ...
# 125    2/3/2020 17:59:12          trondkr@faralloninstitute.org                                                NaN              ['r1i1p1f1']  ['1pctCO2', 'esm-hist', 'esm-ssp585', 'histori...                                            ['All']                                       ['albisccp']      CFmon         Trond Kristiansen  I have previously requested data for an analsy...                                         Thank you!
# 126    2/3/2020 17:59:12          trondkr@faralloninstitute.org                                                NaN              ['r1i1p1f1']  ['1pctCO2', 'esm-hist', 'esm-ssp585', 'histori...                                            ['All']                 ['dissoc', 'dissic', 'chl', 'tos']       Omon         Trond Kristiansen  I have previously requested data for an analsy...                                         Thank you!
# 127     2/8/2020 0:11:43                      nhn2@columbia.edu                                                NaN                   ['All']                                      ['piControl']                                    ['SAM0-UNICON']  ['siconca', 'siconc', 'sisnconc', 'sithick', '...      SImon                     Naomi                                                NaN                                                NaN
# 128   2/23/2020 15:48:48  duncan.watson-parris@physics.ox.ac.uk                                                NaN                   ['One']  ['hist-aer', 'histSST', 'piClim-aer', 'piClim-...                                            ['All']                   ['rsut', 'rlut', 'rsdt', 'rldt']       Amon      Duncan Watson-Parris  Exploring historical and projected (anthropoge...  The associated radiative fluxes (r{s,l}{u,d}t)...
# 129           2020-02-26                         orianac@uw.edu                                                NaN                   ['All']  ['historical', 'ssp126', 'ssp245', 'ssp370', '...                                            ['All']                                           ['hfls']       Amon         Oriana Chegwidden  How will hydrologic droughts, particularly tho...  Thanks so much for your help! Please let me kn...
# 130           2020-02-27                         orianac@uw.edu                                                NaN                   ['All']  ['historical', 'ssp126', 'ssp245', 'ssp370', '...                                            ['All']                          ['mrro', 'mrso', 'mrsos']       Lmon         Oriana Chegwidden  How will hydrologic droughts, particularly tho...  Thanks so much for your help! Please let me kn...
# 131           2020-02-27                         orianac@uw.edu                                                NaN                   ['All']  ['historical', 'ssp126', 'ssp245', 'ssp370', '...                                            ['All']                                            ['snw']      LImon         Oriana Chegwidden  How will hydrologic droughts, particularly tho...  Thanks so much for your help! Please let me kn...

# %% [markdown]
# ### Get new Google Sheet requests
# - by default, only the new rows from the sheet are considered
# - specifying a list of rows or emails will add older entries

# %%
rows = []   
emails = []

# modify here:

#rows = [97]

#emails = ['duncan.watson-parris@physics.ox.ac.uk']

df_request_new, dtrouble = requests(df_prior,rows=rows,emails=emails)

request_id = set_request_id()

# Check for mal-formed requests (non-existent variables, etc)
if len(dtrouble)>=1:
    print(dtrouble)

df_request_new

# %%
# choose a new request to process:
timestamps = df_request_new.Timestamp.unique()
print(timestamps)
#df_request_new = df_request_new[df_request_new.Timestamp == timestamps[-1]]
df_request_new
# Out:
# ['1/29/2020 17:24:30']
#              Timestamp          E-mail response status members                                   experiments models                       variables table          requester                                            science                                           comments
# 97  1/29/2020 17:24:30  orianac@uw.edu             NaN   [All]  [historical, ssp126, ssp245, ssp370, ssp585]  [All]  [mrro, hfls, snw, mrso, mrsos]   day  Oriana Chegwidden  How will hydrologic droughts, particularly tho...  Thanks so much for your help! Please let me kn...

# %% [markdown]
# ### Search ESGF for the availability of requested data

# %%
print(ESGF_site)
df_ESGF = search(ESGF_site,df_request_new)
# Out:
# https://esgf-node.llnl.gov/esg-search/search
#
# orianac@uw.edu
# day mrro ['All'] historical
# day hfls ['All'] historical
# day snw ['All'] historical
# day mrso ['All'] historical
# day mrsos ['All'] historical
# day mrro ['All'] ssp126
# day hfls ['All'] ssp126
# day snw ['All'] ssp126
# day mrso ['All'] ssp126
# day mrsos ['All'] ssp126
# day mrro ['All'] ssp245
# day hfls ['All'] ssp245
# day snw ['All'] ssp245
# day mrso ['All'] ssp245
# day mrsos ['All'] ssp245
# day mrro ['All'] ssp370
# day hfls ['All'] ssp370
# day snw ['All'] ssp370
# day mrso ['All'] ssp370
# day mrsos ['All'] ssp370
# day mrro ['All'] ssp585
# day hfls ['All'] ssp585
# day snw ['All'] ssp585
# day mrso ['All'] ssp585
# day mrsos ['All'] ssp585

# %%
#import qgrid
#qgrid.show_grid(df_ESGF)

# %% [markdown]
# ### Get the master list of existing zarr stores
# - df_master includes all curated stores
# - df_avail includes all stores, even those with known ES-DOC issues

# %%
df_master = pd.read_csv('https://cmip6.storage.googleapis.com/cmip6-zarr-consolidated-stores.csv')
df_avail = pd.read_csv('https://cmip6.storage.googleapis.com/cmip6-zarr-consolidated-stores-noQC.csv')
len(df_master),len(df_avail),len(df_ESGF)
# Out:
# (238543, 239476, 14283)

# %% [markdown]
# ### Check the new requests:
# - already exists in df_master (what we have) - not needed
# - exists in df_ESGF (what is available) - if not available, then not needed

# %%
df_needed = needed(df_avail, df_request_new, df_ESGF)

if len(df_needed) > 0:
    num_stores = df_needed.zstore.nunique() 
    print(f'needed: nfiles={len(df_needed)}, nstores={num_stores}')
    #print(df_needed.zstore.unique())
else:
    print('no new data available')
    exit
# Out:
# needed: nfiles=1549, nstores=37

# %%
import qgrid
qgrid.show_grid(df_needed)
#/DCPP/BCC/BCC-CSM2-MR/dcppA-hindcast/s1961-r1i1p1f1/Amon/tas/gn/
# Out:
# QgridWidget(grid_options={'fullWidthRows': True, 'syncColumnCellResize': True, 'forceFitColumns': True, 'defau…

# %%
df_needed.zstore.unique()
# Out:
# array(['/CMIP/EC-Earth-Consortium/EC-Earth3/historical/r2i1p1f1/day/mrro/gr/',
#        '/CMIP/CAS/FGOALS-f3-L/historical/r1i1p1f1/day/hfls/gr/',
#        '/CMIP/CAS/FGOALS-f3-L/historical/r2i1p1f1/day/hfls/gr/',
#        '/CMIP/CAS/FGOALS-f3-L/historical/r3i1p1f1/day/hfls/gr/',
#        '/CMIP/CAS/FGOALS-g3/historical/r1i1p1f1/day/hfls/gn/',
#        '/CMIP/CAS/FGOALS-g3/historical/r3i1p1f1/day/hfls/gn/',
#        '/CMIP/EC-Earth-Consortium/EC-Earth3/historical/r2i1p1f1/day/hfls/gr/',
#        '/CMIP/NUIST/NESM3/historical/r1i1p1f1/day/hfls/gn/',
#        '/CMIP/NUIST/NESM3/historical/r2i1p1f1/day/hfls/gn/',
#        '/CMIP/NUIST/NESM3/historical/r3i1p1f1/day/hfls/gn/',
#        '/CMIP/NUIST/NESM3/historical/r4i1p1f1/day/hfls/gn/',
#        '/CMIP/NUIST/NESM3/historical/r5i1p1f1/day/hfls/gn/',
#        '/ScenarioMIP/CAS/FGOALS-g3/ssp126/r1i1p1f1/day/hfls/gn/',
#        '/ScenarioMIP/NUIST/NESM3/ssp126/r1i1p1f1/day/hfls/gn/',
#        '/ScenarioMIP/NUIST/NESM3/ssp126/r2i1p1f1/day/hfls/gn/',
#        '/ScenarioMIP/CAS/FGOALS-g3/ssp245/r1i1p1f1/day/hfls/gn/',
#        '/ScenarioMIP/NUIST/NESM3/ssp245/r1i1p1f1/day/hfls/gn/',
#        '/ScenarioMIP/NUIST/NESM3/ssp245/r2i1p1f1/day/hfls/gn/',
#        '/ScenarioMIP/CAS/FGOALS-g3/ssp370/r1i1p1f1/day/hfls/gn/',
#        '/ScenarioMIP/NCAR/CESM2-WACCM/ssp370/r3i1p1f1/day/hfls/gn/',
#        '/ScenarioMIP/CAS/FGOALS-g3/ssp585/r1i1p1f1/day/hfls/gn/',
#        '/ScenarioMIP/NUIST/NESM3/ssp585/r1i1p1f1/day/hfls/gn/',
#        '/ScenarioMIP/NUIST/NESM3/ssp585/r2i1p1f1/day/hfls/gn/',
#        '/CMIP/EC-Earth-Consortium/EC-Earth3/historical/r2i1p1f1/day/snw/gr/',
#        '/CMIP/NUIST/NESM3/historical/r1i1p1f1/day/snw/gn/',
#        '/CMIP/NUIST/NESM3/historical/r2i1p1f1/day/snw/gn/',
#        '/CMIP/NUIST/NESM3/historical/r3i1p1f1/day/snw/gn/',
#        '/CMIP/NUIST/NESM3/historical/r4i1p1f1/day/snw/gn/',
#        '/CMIP/NUIST/NESM3/historical/r5i1p1f1/day/snw/gn/',
#        '/ScenarioMIP/NUIST/NESM3/ssp126/r1i1p1f1/day/snw/gn/',
#        '/ScenarioMIP/NUIST/NESM3/ssp126/r2i1p1f1/day/snw/gn/',
#        '/ScenarioMIP/NUIST/NESM3/ssp245/r1i1p1f1/day/snw/gn/',
#        '/ScenarioMIP/NUIST/NESM3/ssp245/r2i1p1f1/day/snw/gn/',
#        '/ScenarioMIP/NUIST/NESM3/ssp585/r1i1p1f1/day/snw/gn/',
#        '/ScenarioMIP/NUIST/NESM3/ssp585/r2i1p1f1/day/snw/gn/',
#        '/CMIP/EC-Earth-Consortium/EC-Earth3/historical/r2i1p1f1/day/mrso/gr/',
#        '/CMIP/EC-Earth-Consortium/EC-Earth3/historical/r2i1p1f1/day/mrsos/gr/'],
#       dtype=object)

# %%
assert False
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-14-a871fdc9ebee> in <module>
# ----> 1 assert False
#
# AssertionError:

# %% [markdown]
# ### Start logging the progress and exceptions

# %%
cat_file = 'csv/cmip6_'+request_id+'.csv'
log_file = 'txt/request_'+request_id+'.log'

# %%
# open and close for each write in case of kernel interrupt
def write_log(file,str,verbose=True):
    f = open(file,'a')
    if verbose:
        print(str)
    f.write(str+'\n')
    f.close()
    return

# %% [markdown]
# ### The real work is done in this next loop
# - could be done in parallel except for the writing to the log file

# %%
new_zarrs = df_needed.zstore.unique()
verbose = True

zbdirs = []
for i in range(1,65):
    zbdirs += ['/h'+str(i)]

zdict = {}  # construct dictionary for new rows to add to master catalog
for item,zarr in enumerate(new_zarrs):
    #if item < 642:
    #    continue
    
    zbdir  = zarr_local  + zarr
    
    write_log(log_file,f"\n>>{item+1}/{num_stores}:<< local file: {zbdir}",verbose=verbose)
    
    # is zarr already in cloud?
    gsurl = 'gs://cmip6' + zarr
    contents = fs.ls(gsurl+'/.zmetadata')
    if any("zmetadata" in s for s in contents):
        write_log(log_file,'store already in cloud',verbose=verbose)
        continue

    # does zarr exist locally?  Won't need this once all uploads happen immediately
    iexist = False
    for zbdirr in zbdirs:
        zfile = zbdirr + '/naomi/zarr-minimal' + zarr + '.zmetadata'
        if os.path.isfile(zfile):
            write_log(log_file,f'already exists: {zfile}',verbose=verbose)
            iexist = True
            
    if iexist:
        continue
            
    gfiles,troubles,codes = get_ncfiles(zarr,df_needed,skip_sites)
    
    write_log(log_file,troubles,verbose=verbose)
    
    if len(gfiles) == 0: 
        write_log(log_file,'no files available',verbose=verbose)
        continue
    
    variable_id = zarr.split('/')[-3]
    for gfile in gfiles:   # changes file sizes!!
        command = '/usr/bin/ncatted -h -O -a missing_value\,'+variable_id+',d,, '+gfile
        os.system(command)

    # concatenate in time with mfdataset
    #print(gfiles)
    status, ds, dstr = concatenate(zarr,gfiles,codes)  

    if status == 'concatenation failure: ':
        write_log(log_file,status+dstr,verbose=verbose)
        continue
    else:
        write_log(log_file,dstr)

    try:
        del ds[variable_id].encoding['missing_value']
        ds.to_zarr(zbdir, consolidated=True, mode='w')
    except:
        ds.to_zarr(zbdir, consolidated=True, mode='w')
    

    if not os.path.isfile(zbdir+'/.zmetadata'):
        write_log(log_file,'to_zarr failure: ',verbose=verbose)
        continue
   
    vlist = get_details(ds,zbdir,zarr)
    
    # upload to cloud
    command = '/usr/bin/gsutil -m cp -r '+ zbdir[:-1] + ' ' + gsurl[:-1]
    write_log(log_file,command,verbose=verbose)
    os.system(command) 
        
    size_remote = fs.du(gsurl)
    size_local = getFolderSize(zbdir)
    assert (size_remote - size_local) < 100
# Out:
# >>1/37:<< local file: /h63/naomi/zarr-minimal/CMIP/EC-Earth-Consortium/EC-Earth3/historical/r2i1p1f1/day/mrro/gr/
# noUse in codes
# no files available
#
# >>2/37:<< local file: /h63/naomi/zarr-minimal/CMIP/CAS/FGOALS-f3-L/historical/r1i1p1f1/day/hfls/gr/
# 	skipping esg.lasg.ac.cn domain
# no files available
#
# >>3/37:<< local file: /h63/naomi/zarr-minimal/CMIP/CAS/FGOALS-f3-L/historical/r2i1p1f1/day/hfls/gr/
# 	skipping esg.lasg.ac.cn domain
# no files available
#
# >>4/37:<< local file: /h63/naomi/zarr-minimal/CMIP/CAS/FGOALS-f3-L/historical/r3i1p1f1/day/hfls/gr/
# 	skipping esg.lasg.ac.cn domain
# no files available
#
# >>5/37:<< local file: /h63/naomi/zarr-minimal/CMIP/CAS/FGOALS-g3/historical/r1i1p1f1/day/hfls/gn/
# 	skipping esg.lasg.ac.cn domain
# no files available
#
# >>6/37:<< local file: /h63/naomi/zarr-minimal/CMIP/CAS/FGOALS-g3/historical/r3i1p1f1/day/hfls/gn/
# 	skipping esg.lasg.ac.cn domain
# no files available
#
# >>7/37:<< local file: /h63/naomi/zarr-minimal/CMIP/EC-Earth-Consortium/EC-Earth3/historical/r2i1p1f1/day/hfls/gr/
# noUse in codes
# no files available
#
# >>8/37:<< local file: /h63/naomi/zarr-minimal/CMIP/NUIST/NESM3/historical/r1i1p1f1/day/hfls/gn/
# 	skipping esg.lasg.ac.cn domain
# no files available
#
# >>9/37:<< local file: /h63/naomi/zarr-minimal/CMIP/NUIST/NESM3/historical/r2i1p1f1/day/hfls/gn/
# 	skipping esg.lasg.ac.cn domain
# no files available
#
# >>10/37:<< local file: /h63/naomi/zarr-minimal/CMIP/NUIST/NESM3/historical/r3i1p1f1/day/hfls/gn/
# 	skipping esg.lasg.ac.cn domain
# no files available
#
# >>11/37:<< local file: /h63/naomi/zarr-minimal/CMIP/NUIST/NESM3/historical/r4i1p1f1/day/hfls/gn/
# 	skipping esg.lasg.ac.cn domain
# no files available
#
# >>12/37:<< local file: /h63/naomi/zarr-minimal/CMIP/NUIST/NESM3/historical/r5i1p1f1/day/hfls/gn/
# 	skipping esg.lasg.ac.cn domain
# no files available
#
# >>13/37:<< local file: /h63/naomi/zarr-minimal/ScenarioMIP/CAS/FGOALS-g3/ssp126/r1i1p1f1/day/hfls/gn/
# 	skipping esg.lasg.ac.cn domain
# no files available
#
# >>14/37:<< local file: /h63/naomi/zarr-minimal/ScenarioMIP/NUIST/NESM3/ssp126/r1i1p1f1/day/hfls/gn/
# 	skipping esg.lasg.ac.cn domain
# no files available
#
# >>15/37:<< local file: /h63/naomi/zarr-minimal/ScenarioMIP/NUIST/NESM3/ssp126/r2i1p1f1/day/hfls/gn/
# 	skipping esg.lasg.ac.cn domain
# no files available
#
# >>16/37:<< local file: /h63/naomi/zarr-minimal/ScenarioMIP/CAS/FGOALS-g3/ssp245/r1i1p1f1/day/hfls/gn/
# 	skipping esg.lasg.ac.cn domain
# no files available
#
# >>17/37:<< local file: /h63/naomi/zarr-minimal/ScenarioMIP/NUIST/NESM3/ssp245/r1i1p1f1/day/hfls/gn/
# 	skipping esg.lasg.ac.cn domain
# no files available
#
# >>18/37:<< local file: /h63/naomi/zarr-minimal/ScenarioMIP/NUIST/NESM3/ssp245/r2i1p1f1/day/hfls/gn/
# 	skipping esg.lasg.ac.cn domain
# no files available
#
# >>19/37:<< local file: /h63/naomi/zarr-minimal/ScenarioMIP/CAS/FGOALS-g3/ssp370/r1i1p1f1/day/hfls/gn/
# 	skipping esg.lasg.ac.cn domain
# no files available
#
# >>20/37:<< local file: /h63/naomi/zarr-minimal/ScenarioMIP/NCAR/CESM2-WACCM/ssp370/r3i1p1f1/day/hfls/gn/
# noUse in codes
# no files available
#
# >>21/37:<< local file: /h63/naomi/zarr-minimal/ScenarioMIP/CAS/FGOALS-g3/ssp585/r1i1p1f1/day/hfls/gn/
# 	skipping esg.lasg.ac.cn domain
# no files available
#
# >>22/37:<< local file: /h63/naomi/zarr-minimal/ScenarioMIP/NUIST/NESM3/ssp585/r1i1p1f1/day/hfls/gn/
# 	skipping esg.lasg.ac.cn domain
# no files available
#
# >>23/37:<< local file: /h63/naomi/zarr-minimal/ScenarioMIP/NUIST/NESM3/ssp585/r2i1p1f1/day/hfls/gn/
# 	skipping esg.lasg.ac.cn domain
# no files available
#
# >>24/37:<< local file: /h63/naomi/zarr-minimal/CMIP/EC-Earth-Consortium/EC-Earth3/historical/r2i1p1f1/day/snw/gr/
# noUse in codes
# no files available
#
# >>25/37:<< local file: /h63/naomi/zarr-minimal/CMIP/NUIST/NESM3/historical/r1i1p1f1/day/snw/gn/
# 	skipping esg.lasg.ac.cn domain
# no files available
#
# >>26/37:<< local file: /h63/naomi/zarr-minimal/CMIP/NUIST/NESM3/historical/r2i1p1f1/day/snw/gn/
# 	skipping esg.lasg.ac.cn domain
# no files available
#
# >>27/37:<< local file: /h63/naomi/zarr-minimal/CMIP/NUIST/NESM3/historical/r3i1p1f1/day/snw/gn/
# 	skipping esg.lasg.ac.cn domain
# no files available
#
# >>28/37:<< local file: /h63/naomi/zarr-minimal/CMIP/NUIST/NESM3/historical/r4i1p1f1/day/snw/gn/
# 	skipping esg.lasg.ac.cn domain
# no files available
#
# >>29/37:<< local file: /h63/naomi/zarr-minimal/CMIP/NUIST/NESM3/historical/r5i1p1f1/day/snw/gn/
# 	skipping esg.lasg.ac.cn domain
# no files available
#
# >>30/37:<< local file: /h63/naomi/zarr-minimal/ScenarioMIP/NUIST/NESM3/ssp126/r1i1p1f1/day/snw/gn/
# 	skipping esg.lasg.ac.cn domain
# no files available
#
# >>31/37:<< local file: /h63/naomi/zarr-minimal/ScenarioMIP/NUIST/NESM3/ssp126/r2i1p1f1/day/snw/gn/
# 	skipping esg.lasg.ac.cn domain
# no files available
#
# >>32/37:<< local file: /h63/naomi/zarr-minimal/ScenarioMIP/NUIST/NESM3/ssp245/r1i1p1f1/day/snw/gn/
# 	skipping esg.lasg.ac.cn domain
# no files available
#
# >>33/37:<< local file: /h63/naomi/zarr-minimal/ScenarioMIP/NUIST/NESM3/ssp245/r2i1p1f1/day/snw/gn/
# 	skipping esg.lasg.ac.cn domain
# no files available
#
# >>34/37:<< local file: /h63/naomi/zarr-minimal/ScenarioMIP/NUIST/NESM3/ssp585/r1i1p1f1/day/snw/gn/
# 	skipping esg.lasg.ac.cn domain
# no files available
#
# >>35/37:<< local file: /h63/naomi/zarr-minimal/ScenarioMIP/NUIST/NESM3/ssp585/r2i1p1f1/day/snw/gn/
# 	skipping esg.lasg.ac.cn domain
# no files available
#
# >>36/37:<< local file: /h63/naomi/zarr-minimal/CMIP/EC-Earth-Consortium/EC-Earth3/historical/r2i1p1f1/day/mrso/gr/
# noUse in codes
# no files available
#
# >>37/37:<< local file: /h63/naomi/zarr-minimal/CMIP/EC-Earth-Consortium/EC-Earth3/historical/r2i1p1f1/day/mrsos/gr/
# noUse in codes
# no files available

# %% [markdown]
# ### Make a table of acquired data to send in email to requestor

# %%
if len(zdict) == 0 :
    print('nothing else to do')
    exit
else:
    dz = dict_to_dfcat(zdict)

# %%
assert False

# %%
try:
    df_master_new = pd.concat([df_master, dz])
except:
    df_master_new = df_master

# %%
#df_master_new = df_master

# %%
from response import response, dict_to_dfcat, get_details
from IPython.display import display

ldict = []
names = ""
print('Re: CMIP6 GCS Data Request (Responses)')
for row in df_request_new.values:
    rdict = dict(zip(df_request_new.keys(),row))
    #print(rdict)
    name = rdict['requester']
    timestamp = rdict['Timestamp']
    names += name
    del rdict['response status']
    ldict += [rdict]
    dfr = df_request_new[df_request_new.Timestamp == timestamp]
    
    print('Dear',name+':')
    print('\n  Here are the results from your recent CMIP6 data request(s).  The master catalog will be updated with the nightly build.')
    #if len(dtrouble)>=1:
    #    print('\n '+dtrouble)
    print('\n  Please note: ')
    print('      - Data for some models (e.g., CAS/FGOALS-f3-L and NUIST/NESM3) must be obtained directly from servers which are too slow or unresponsive. ')
    print('      - We exclude data with known errors (as reported at ES-DOC) from the official data catalog, https://errata.es-doc.org/ . ')
    print('      - Some data we have not been able to clean up enough to get it concatenated and save to zarr. Other datasets are only available for disjointed time periods.')
    print('\n  See the sample Jupyter Notebook at https://gist.github.com/naomi-henderson/ed1801d8ee8b992dda252f8b126876a5 for a quick introduction to accessing the data.')
    print('\nFrom the folks at:\n  The Climate Data Science Lab\n  Division of Ocean and Climate Physics\n  LDEO/Columbia University')
    print('\n--------------------------')

    print('\nrequest:')
    display(rdict)

    print('\nresponse:')
    try:
        print('new stores added:\n',len(dz),'\n')
    except:
        print(f'no new data available at ESGF API search node {ESGF_site}')

    #print('\n',dfr,len(df_master_new))
    table = response(dfr,df_master_new)

    print("\navailable data:\n  this includes your new stores but does not include datasets marked 'onhold', 'wontfix' or 'new' in the ES-DOC ERRATA")
    display(table)
    print('\n\n')

# %%
! mv csv/request_new.csv csv/requests.csv

# %%
file = 'nctemp/mrso_Lmon_SAM0-UNICON_piControl_r1i1p1f1_gn_028101-029112.nc'
ds = xr.open_dataset(file)

# %%
ds.time.dt.year

# %%
ds.attrs
